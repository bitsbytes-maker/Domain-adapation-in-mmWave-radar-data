# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from scipy.spatial.distance import cdist
import random
import os
import sys
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import numpy as np

from torchvision import datasets
from torchvision import transforms

# %%
import pandas as pd
import numpy as np
import random
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.preprocessing import Normalizer


tform1 = StandardScaler()
tform=transforms.Compose([
                           transforms.ToTensor()])
def fileFeedforGNN(name):

  data = pd.read_csv(name)

  

  y = data.iloc[:,-2].values
  
  
  print(np.unique(y))


  graphList = []
  

# 'dime' 'leadpencil' 'plasticsheet' 'quarter' 'wood'
    
  #num_objects	r_std	r_var	r_mean	r_min	r_max	snr_std	snr_var	snr_mean	snr_min	snr_max	noise_std	noise_var	noise_mean	noise_min	noise_max	obj	environment	
  X_array = data.iloc[:, 0:16].values

  X_array = tform1.fit_transform(X_array)
  

  addList_bot, addList_clothes, addList_plastics, addList_steel,addList_paper  = [],[],[],[],[]
    
  for i in range(len(X_array)):
    intarray = X_array[i]
    if(y[i] =='bot' or y[i] == 'dime'):
      addList_bot.append(intarray)
    elif (y[i] == 'clothes' or  y[i] == 'leadpencil' ):
      addList_clothes.append(intarray)
    elif (y[i] == 'plastic' or y[i] == 'plasticsheet'):
      addList_plastics.append(intarray)
    elif (y[i] == 'steel' or y[i] == 'quarter'):
      addList_steel.append(intarray)
    elif (y[i] == 'paper' or y[i] == 'wood'):
      addList_paper.append(intarray)
  
  len_img = 40
  for i in range(len(addList_bot) - (len_img-1) ):
    
    
        #img = addList_bot[i]
        
        img = np.array(addList_bot[i:i+len_img])
        img = np.reshape(img, (1,len_img*16))
        
        # if(i<1):
        #     print(img.shape)
        #     print(img)
        
        graphList.append((img,0))

  for i in range(len(addList_clothes)  - len_img-1):
    
        #img = addList_clothes[i]
    
        img = np.array(addList_clothes[i:i+len_img])
        img = np.reshape(img, (1,len_img*16))      
        # if(i<1):
        #     print(img)
        
        graphList.append(((img),1))
        
  for i in range(len(addList_plastics) - len_img-1):
        
        #img = addList_plastics[i]
        img = np.array(addList_plastics[i:i+len_img])
        img = np.reshape(img, (1,len_img*16))    
        # if(i<1):
        #     print(img)
            
        graphList.append(((img),2))
        
  for i in range(len(addList_steel) - len_img-1):
        #img = addList_steel[i]
    
        img = np.array(addList_steel[i:i+len_img])
        img = np.reshape(img, (1,len_img*16))       
        # if(i<1):
        #     print(img)
        graphList.append(((img),4))
  for i in range(len(addList_paper) - len_img-1):
    #img = addList_steel[i]

        img = np.array(addList_paper[i:i+len_img])
        img = np.reshape(img, (1,len_img*16))       
        # if(i<1):
        #     print(img)
        graphList.append(((img),3))
  
  
  
  print(len(graphList))
    
    
 
  return graphList




############################## data loading for 3.5 inch#####################

graphList_lablight_3_5 = fileFeedforGNN('lablight_data_7.txt')
graphList_night_3_5 = fileFeedforGNN('dark_data_7.txt')
graphList_sunny_3_5 = fileFeedforGNN('sunny_data_7.txt')


lablight_train_len = int(len(graphList_lablight_3_5)*0.7)
night_train_len = int(len(graphList_night_3_5)*0.7)
sunny_tarin_len = int(len(graphList_sunny_3_5)*0.7)


batch_size=64
test_batch_size=64

random.shuffle(graphList_lablight_3_5)
random.shuffle(graphList_night_3_5)
random.shuffle(graphList_sunny_3_5)

train_loader_lablight_3_5 = torch.utils.data.DataLoader(graphList_lablight_3_5[0:lablight_train_len],batch_size)  
test_loader_lablight_3_5 = torch.utils.data.DataLoader(graphList_lablight_3_5[lablight_train_len:],test_batch_size) 

train_loader_night_3_5 = torch.utils.data.DataLoader(graphList_night_3_5[0:night_train_len],batch_size)  
test_loader_night_3_5 = torch.utils.data.DataLoader(graphList_night_3_5[night_train_len:],test_batch_size) 

train_loader_sunny_3_5 = torch.utils.data.DataLoader(graphList_sunny_3_5[0:sunny_tarin_len],batch_size)  
test_loader_sunny_3_5 = torch.utils.data.DataLoader(graphList_sunny_3_5[sunny_tarin_len:],test_batch_size) 

print(len(graphList_lablight_3_5))
print(len(graphList_night_3_5))
print(len(graphList_sunny_3_5))



############################## data loading for 7 inch#####################

graphList_lablight_7= fileFeedforGNN('lablight_data_53.txt')
graphList_night_7 = fileFeedforGNN('dark_data_53.txt')
graphList_sunny_7 = fileFeedforGNN('sunny_data_53.txt')


lablight_train_len = int(len(graphList_lablight_7)*0.7)
night_train_len = int(len(graphList_night_7)*0.7)
sunny_tarin_len = int(len(graphList_sunny_7)*0.7)



random.shuffle(graphList_lablight_7)
random.shuffle(graphList_night_7)
random.shuffle(graphList_sunny_7)

train_loader_lablight_7 = torch.utils.data.DataLoader(graphList_lablight_7[0:lablight_train_len],batch_size)  
test_loader_lablight_7 = torch.utils.data.DataLoader(graphList_lablight_7[lablight_train_len:],test_batch_size) 

train_loader_night_7 = torch.utils.data.DataLoader(graphList_night_7[0:night_train_len],batch_size)  
test_loader_night_7 = torch.utils.data.DataLoader(graphList_night_7[night_train_len:],test_batch_size) 

train_loader_sunny_7= torch.utils.data.DataLoader(graphList_sunny_7[0:sunny_tarin_len],batch_size)  
test_loader_sunny_7= torch.utils.data.DataLoader(graphList_sunny_7[sunny_tarin_len:],test_batch_size) 

print(len(test_loader_sunny_7)*64)

print(len(graphList_lablight_7))
print(len(graphList_night_7))
print(len(graphList_sunny_7))



print(len(train_loader_sunny_7))
# Out:
# ['dime' 'leadpencil' 'plasticsheet' 'quarter' 'wood']
# 18032
# ['dime' 'leadpencil' 'plasticsheet' 'quarter' 'wood']
# 17975
# ['dime' 'leadpencil' 'plasticsheet' 'quarter' 'wood']
# 18345
# 18032
# 17975
# 18345
# ['dime' 'leadpencil' 'plasticsheet' 'quarter' 'wood']
# 19774
# ['dime' 'leadpencil' 'plasticsheet' 'quarter' 'wood']
# 16723
# ['dime' 'leadpencil' 'plasticsheet' 'quarter' 'wood']
# 16228
# 4928
# 19774
# 16723
# 16228
# 178

# %%
def fun(train_loader_sunny_7):

  llList = []

  for r in range(2):

    data_source_iter = iter(train_loader_sunny_7)
    for i in range(len(train_loader_sunny_7)):
      
      data_source = next(data_source_iter)
      s_img, s_label = data_source

      llList.append(s_label)

  return llList


print(fun(train_loader_sunny_7))
print(fun(train_loader_sunny_7))
print(fun(train_loader_sunny_7))
print(fun(train_loader_sunny_7))
print(fun(train_loader_sunny_7))
print(fun(train_loader_sunny_7))

# %%
import torch.utils.data as data
from PIL import Image
import os
import os
import torch.backends.cudnn as cudnn
import torch.utils.data
from torchvision import transforms

from torchvision import datasets

from torch.autograd import Function






import torch.nn as nn

conv_row,conv_col = 1,64
out_channel = 1


output_class = 5
class CNNModel(nn.Module):

    def __init__(self):
        super(CNNModel, self).__init__()
        self.feature = nn.Sequential()
        
        self.feature.add_module('f_conv1',nn.Conv1d(1, 2, 20,2))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_conv2',nn.Conv1d(2, 2, 20,2))
        self.feature.add_module('f_relu2', nn.ReLU(True))
        self.feature.add_module('f_conv3',nn.Conv1d(2, 1, 20,2))
        self.feature.add_module('f_relu3', nn.ReLU(True))
        # self.feature.add_module('f_conv4',nn.Conv1d(2, 1, 20,2))
        # self.feature.add_module('f_relu4', nn.ReLU(True))
        

        
     
       


        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(conv_row * conv_col * out_channel, 32))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_fc2', nn.Linear(32, 16))
        self.class_classifier.add_module('c_relu2', nn.ReLU(True))
        self.class_classifier.add_module('c_fc3', nn.Linear(16, output_class))
        self.class_classifier.add_module('c_softmax', nn.Softmax(dim=1))

        
    def forward(self, input_data, alpha=0):
        #input_data = input_data.expand(input_data.data.shape[0], 3, 28, 28)
        # print("I am in forward")
        # print(input_data.data.shape[0])
        input_data = input_data.float()
        feature = self.feature(input_data)
        #print(feature.shape)
        feature = feature.view(-1, conv_row * conv_col * out_channel)
        
        class_output = self.class_classifier(feature)
        

        return feature,class_output

    



def test(my_net,dataloader):
    #assert dataset_name in ['MNIST', 'mnist_m']

    model_root = ''
    

    cuda = True
    cudnn.benchmark = True

   
  

    my_net = my_net.eval()

    if cuda:
        my_net = my_net.cuda()

    len_dataloader = len(dataloader)
    data_target_iter = iter(dataloader)

    i = 0
    n_total = 0
    n_correct = 0

    while i < len_dataloader:

        # test model using target data
        data_target = next(data_target_iter)
        t_img, t_label = data_target
        
        

        batch_size = len(t_label)

        if cuda:
            t_img = t_img.cuda()
            t_label = t_label.cuda()

        feature,class_output = my_net(input_data=t_img)
        pred = class_output.data.max(1, keepdim=True)[1]
        #print(pred)
        n_correct += pred.eq(t_label.data.view_as(pred)).cpu().sum()
        n_total += batch_size

        i += 1

    accu = n_correct.data.numpy() * 1.0 / n_total

    return accu

# %%
import random
import os
import sys
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import numpy as np

from torchvision import datasets
from torchvision import transforms

import torch.distributions as td




def modelTrainer(train_loader_source,test_loader_source):
    model_root = 'models'
    cuda = True
    cudnn.benchmark = True
    lr = 1e-3


    n_epoch = 300

    manual_seed = random.randint(1, 10000)
    random.seed(manual_seed)
    torch.manual_seed(manual_seed)

    # load data

    dataloader_source = train_loader_source


    

    my_net = CNNModel()

    # setup optimizer

    optimizer = optim.Adam(my_net.parameters(), lr=lr)

    loss_class = torch.nn.CrossEntropyLoss()
    loss_domain = torch.nn.CrossEntropyLoss()

    if cuda:
        my_net = my_net.cuda()
        loss_class = loss_class.cuda()
        

    for p in my_net.parameters():
        p.requires_grad = True

    # training
    best_accu_s = 0.0

    accList = []
    errList = []

    for epoch in range(n_epoch):

        len_dataloader = len(dataloader_source)
        data_source_iter = iter(dataloader_source)
        


        #print(len_dataloader)

        for i in range(len_dataloader):

          

            # training model using source data
            data_source = next(data_source_iter)
            s_img, s_label = data_source

            # print('\n')
            # print(s_img.shape)
            # print(s_label)

            my_net.zero_grad()
          
            

            if cuda:
                s_img = s_img.cuda()
                s_label = s_label.cuda()
                


            source_feature, class_output= my_net(input_data=s_img)
            err_s_label = loss_class(class_output, s_label)
            

           


            err = err_s_label 
            

            err.backward()



            optimizer.step()
            optimizer.zero_grad()
            errList.append(err)

            # sys.stdout.write('\r epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
            #       % (epoch, i + 1, len_dataloader, err_s_label.data.cpu().numpy(),
            #          err_s_domain.data.cpu().numpy(), err_t_domain.data.cpu().item()))
            # sys.stdout.flush()
            #torch.save(my_net, 'mnist_mnistm_model_epoch_current.pth'.format(model_root))

        #print('\n')
        accu_s = test(my_net,test_loader_source)
       # print('Accuracy of the %s dataset: %f' % ('source===', accu_s))
        #accu_t = test(my_net,test_loader_target)
        #print('Accuracy of the %s dataset: %f\n' % ('target', accu_t))
        accList.append(accu_s)
        if accu_s > best_accu_s:
            best_accu_s = accu_s
            #best_accu_t = accu_t
            torch.save(my_net, 'mnist_mnistm_model_epoch_best.pth'.format(model_root))

    print('============ Summary ============= \n')
    print('Accuracy of the %s dataset: %f' % ('source', best_accu_s))
    
    print('Corresponding model was save in ' + model_root + 'mnist_mnistm_model_epoch_best.pth')
    
    
    del train_loader_source
    del test_loader_source
    
    
    return accList,errList



print("train sunny and test sunny")
accList_3_5_sunny,lossList_3_5_sunny = modelTrainer(train_loader_sunny_3_5,test_loader_sunny_3_5)
    
for i in range(5):
    print('next again=================for_---84')
    print("\n")
    
    print("train sunny and test sunny")
    accList_7_sunny,lossList_7_sunny = modelTrainer(train_loader_sunny_7,test_loader_sunny_7)
    print("train night and test night")
    accList_7_night,lossList_7_night = modelTrainer(train_loader_night_7,test_loader_night_7)
    
    print("train lablight and test lablight")
    accList_7_lablight,lossList_7_lablight = modelTrainer(train_loader_lablight_7,test_loader_lablight_7)
   
    print("train lablight and test night")
    accList_7_lab_night,lossList_7_lab_night = modelTrainer(train_loader_lablight_7,test_loader_night_7)
    print("train lablight and test sunny")
    accList_7_lab_sunny,lossList_7_lab_sunny = modelTrainer(train_loader_lablight_7,test_loader_sunny_7)
    print("train night and test lablight")
    accList_7_night_lab,lossList_7_night_lab = modelTrainer(train_loader_night_7,test_loader_lablight_7)
    print("train night and test sunny")
    accList_7_night_sunny,lossList_7_night_sunny = modelTrainer(train_loader_night_7,test_loader_sunny_7)
    print("train sunny and test night")
    accList_7_sunny_night,lossList_7_sunny_night = modelTrainer(train_loader_sunny_7,test_loader_night_7)
    print("train sunny and test lablight")
    accList_7_sunny_lab,lossList_7_sunny_lab = modelTrainer(train_loader_sunny_7,test_loader_lablight_7)
    
    print('next again=================for___42')
    print("\n")
    
    
    print("train sunny and test sunny")
    accList_3_5_sunny,lossList_3_5_sunny = modelTrainer(train_loader_sunny_3_5,test_loader_sunny_3_5)
    print("train night and test night")
    accList_3_5_night,lossList_3_5_night = modelTrainer(train_loader_night_3_5,test_loader_night_3_5)
    
    print("train lablight and test lablight")
    accList_3_5_lablight,lossList_3_5_lablight = modelTrainer(train_loader_lablight_3_5,test_loader_lablight_3_5)
    
    print("train lablight and test night")
    accList_3_5_lab_night,lossList_3_5_lab_night = modelTrainer(train_loader_lablight_3_5,test_loader_night_3_5)
    print("train lablight and test sunny")
    accList_3_5_lab_sunny,lossList_3_5_lab_sunny = modelTrainer(train_loader_lablight_3_5,test_loader_sunny_3_5)
    print("train night and test lablight")
    accList_3_5_night_lab,lossList_3_5_night_lab = modelTrainer(train_loader_night_3_5,test_loader_lablight_3_5)
    print("train night and test sunny")
    accList_3_5_night_sunny,lossList_3_5_night_sunny = modelTrainer(train_loader_night_3_5,test_loader_sunny_3_5)
    print("train sunny and test night")
    accList_3_5_sunny_night,lossList_3_5_sunny_night = modelTrainer(train_loader_sunny_3_5,test_loader_night_3_5)
    print("train sunny and test lablight")
    accList_3_5_sunny_lab,lossList_3_5_sunny_lab = modelTrainer(train_loader_sunny_3_5,test_loader_lablight_3_5)



    print('next again=================for_---84___to_42')
    print("\n")
    
    print("train sunny and test sunny")
    accList_7_sunny,lossList_7_sunny = modelTrainer(train_loader_sunny_7,test_loader_sunny_3_5)
    print("train night and test night")
    accList_7_night,lossList_7_night = modelTrainer(train_loader_night_7,test_loader_night_3_5)
    
    print("train lablight and test lablight")
    accList_7_lablight,lossList_7_lablight = modelTrainer(train_loader_lablight_7,test_loader_lablight_3_5)


    print('next again=================for_---42___to_84')
    print("\n")
    
    print("train sunny and test sunny")
    accList_7_sunny,lossList_7_sunny = modelTrainer(train_loader_sunny_3_5,test_loader_sunny_7)
    print("train night and test night")
    accList_7_night,lossList_7_night = modelTrainer(train_loader_night_3_5,test_loader_night_7)
    
    print("train lablight and test lablight")
    accList_7_lablight,lossList_7_lablight = modelTrainer(train_loader_lablight_3_5,test_loader_lablight_7)
# Out:
# next again=================for_---84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.999384
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.838549
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.846452
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.221248
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.313822
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.335749
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.232081
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.178792
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.187763
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for___42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.999637
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.997589
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.903882
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.447803
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.372093
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.354159
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.542151
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.421843
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.472089
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---84___to_42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.230741
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.233822
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.302403
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---42___to_84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.303964
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.183576
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.271701
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.998152
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 1.000000
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.852183
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.254933
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.227973
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.113602
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.367427
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.272274
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.182538
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for___42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 1.000000
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.980716
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.952126
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.549416
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.523619
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.510906
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.261083
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.309846
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.321996
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---84___to_42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.415516
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.150009
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.351201
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---42___to_84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.193880
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.165238
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.316366
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.877593
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.841937
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.860610
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.279450
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.080099
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.285859
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.294516
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.352800
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.191134
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for___42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.999637
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.998887
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.898891
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.522715
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.447674
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.483364
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.244549
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.380308
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.357671
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---84___to_42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.257812
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.093825
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.336599
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---42___to_84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.147669
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.296193
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.359852
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 1.000000
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.990433
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.862464
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.216663
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.317108
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.106186
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.356952
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.209089
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.156413
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for___42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 1.000000
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.999444
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.941959
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.561839
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.087573
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.441220
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.343932
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.443352
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.382255
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---84___to_42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.314680
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.203226
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.329205
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---42___to_84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.192853
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.353797
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.246081
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.994865
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.999203
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.893814
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.223640
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.112754
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.266307
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.290819
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.209089
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.256026
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for___42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.999818
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.997589
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.907024
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.456147
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.365371
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.351756
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.541606
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.457630
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train sunny and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.486876
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---84___to_42
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.237645
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.217319
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.302588
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# next again=================for_---42___to_84
#
#
# train sunny and test sunny
# ============ Summary =============
#
# Accuracy of the source dataset: 0.355514
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train night and test night
# ============ Summary =============
#
# Accuracy of the source dataset: 0.247359
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
# train lablight and test lablight
# ============ Summary =============
#
# Accuracy of the source dataset: 0.269678
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth

# %%
# Out:
# tensor(-0.5965)
