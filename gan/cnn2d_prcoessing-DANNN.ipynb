# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from scipy.spatial.distance import cdist

import random
import os
import sys
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import numpy as np

from torchvision import datasets
from torchvision import transforms

# %%
import pandas as pd
import numpy as np
import random
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
tform1 = StandardScaler()
tform=transforms.Compose([
                           transforms.ToTensor()])
def fileFeedforGNN(name):

  data = pd.read_table(name)

  

  y = data.iloc[:,-3].values
  
  
  print(np.unique(y))


  graphList = []
  


    
  #num_objects	r_std	r_var	r_mean	r_min	r_max	snr_std	snr_var	snr_mean	snr_min	snr_max	noise_std	noise_var	noise_mean	noise_min	noise_max	obj	environment	
  X_array = data.iloc[:, 0:16].values

  X_array = tform1.fit_transform(X_array)
  

  addList_bot, addList_clothes, addList_plastics, addList_steel  = [],[],[],[]
    
  for i in range(len(X_array)):
    intarray = X_array[i]
    if(y[i] =='bot'):
      addList_bot.append(intarray)
    elif (y[i] == 'clothes'):
      addList_clothes.append(intarray)
    elif (y[i] == 'plastic'):
      addList_plastics.append(intarray)
    elif (y[i] == 'steel'):
      addList_steel.append(intarray)
  
  len_img = 40
  for i in range(len(addList_bot) - (len_img-1) ):
    
    
        #img = addList_bot[i]
        
        img = np.array(addList_bot[i:i+len_img])
        #img = np.reshape(img, (1,len_img*16))
        
        if(i<1):
            print(img.shape)
           # print(img)
        
        graphList.append((img,0))

  for i in range(len(addList_clothes)  - len_img-1):
    
        #img = addList_clothes[i]
    
        img = np.array(addList_clothes[i:i+len_img])
        #img = np.reshape(img, (1,len_img*16))      
        #if(i<1):
            #print(img)
        
        graphList.append(((img),1))
        
  for i in range(len(addList_plastics) - len_img-1):
        
        #img = addList_plastics[i]
        img = np.array(addList_plastics[i:i+len_img])
        #img = np.reshape(img, (1,len_img*16))    
        #if(i<1):
           # print(img)
            
        graphList.append(((img),2))
        
  for i in range(len(addList_steel) - len_img-1):
        #img = addList_steel[i]
    
        img = np.array(addList_steel[i:i+len_img])
        #img = np.reshape(img, (1,len_img*16))       
        #if(i<1):
            #print(img)
        graphList.append(((img),3))
  
  
  
  print(len(graphList))
    
    
 
  return graphList




############################## data loading for 3.5 inch#####################

graphList_lablight_3_5 = fileFeedforGNN('lablight_3.5_.txt')
graphList_night_3_5 = fileFeedforGNN('night_3.5_.txt')
graphList_sunny_3_5 = fileFeedforGNN('sunny_3.5_.txt')


lablight_train_len = int(len(graphList_lablight_3_5)*0.7)
night_train_len = int(len(graphList_night_3_5)*0.7)
sunny_tarin_len = int(len(graphList_sunny_3_5)*0.7)


batch_size=64
test_batch_size=64

random.shuffle(graphList_lablight_3_5)
random.shuffle(graphList_night_3_5)
random.shuffle(graphList_sunny_3_5)

train_loader_lablight_3_5 = torch.utils.data.DataLoader(graphList_lablight_3_5[0:lablight_train_len],batch_size)  
test_loader_lablight_3_5 = torch.utils.data.DataLoader(graphList_lablight_3_5[lablight_train_len:],test_batch_size) 

train_loader_night_3_5 = torch.utils.data.DataLoader(graphList_night_3_5[0:night_train_len],batch_size)  
test_loader_night_3_5 = torch.utils.data.DataLoader(graphList_night_3_5[night_train_len:],test_batch_size) 

train_loader_sunny_3_5 = torch.utils.data.DataLoader(graphList_sunny_3_5[0:sunny_tarin_len],batch_size)  
test_loader_sunny_3_5 = torch.utils.data.DataLoader(graphList_sunny_3_5[sunny_tarin_len:],test_batch_size) 

print(len(graphList_lablight_3_5))
print(len(graphList_night_3_5))
print(len(graphList_sunny_3_5))



############################## data loading for 7 inch#####################

graphList_lablight_7= fileFeedforGNN('lablight_7_.txt')
graphList_night_7 = fileFeedforGNN('night_7_.txt')
graphList_sunny_7 = fileFeedforGNN('sunny_7_.txt')


lablight_train_len = int(len(graphList_lablight_7)*0.7)
night_train_len = int(len(graphList_night_7)*0.7)
sunny_tarin_len = int(len(graphList_sunny_7)*0.7)


batch_size=64
test_batch_size=64

random.shuffle(graphList_lablight_7)
random.shuffle(graphList_night_7)
random.shuffle(graphList_sunny_7)

train_loader_lablight_7 = torch.utils.data.DataLoader(graphList_lablight_7[0:lablight_train_len],batch_size)  
test_loader_lablight_7 = torch.utils.data.DataLoader(graphList_lablight_7[lablight_train_len:],test_batch_size) 

train_loader_night_7 = torch.utils.data.DataLoader(graphList_night_7[0:night_train_len],batch_size)  
test_loader_night_7 = torch.utils.data.DataLoader(graphList_night_7[night_train_len:],test_batch_size) 

train_loader_sunny_7= torch.utils.data.DataLoader(graphList_sunny_7[0:sunny_tarin_len],batch_size)  
test_loader_sunny_7= torch.utils.data.DataLoader(graphList_sunny_7[sunny_tarin_len:],test_batch_size) 

print(len(test_loader_sunny_7)*64)

print(len(graphList_lablight_7))
print(len(graphList_night_7))
print(len(graphList_sunny_7))
# Out:
# ['bot' 'clothes' 'plastic' 'steel']
# (40, 16)
# 4054
# ['bot' 'clothes' 'plastic' 'steel']
# (40, 16)
# 3545
# ['bot' 'clothes' 'plastic' 'steel']
# (40, 16)
# 3532
# 4054
# 3545
# 3532
# ['bot' 'clothes' 'plastic' 'steel']
# (40, 16)
# 3822
# ['bot' 'clothes' 'plastic' 'steel']
# (40, 16)
# 3773
# ['bot' 'clothes' 'plastic' 'steel']
# (40, 16)
# 3415
# 1088
# 3822
# 3773
# 3415

# %%
import torch.utils.data as data
from PIL import Image
import os
import os
import torch.backends.cudnn as cudnn
import torch.utils.data
from torchvision import transforms

from torchvision import datasets

from torch.autograd import Function


class ReverseLayerF(Function):

    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None




import torch.nn as nn

conv_row,conv_col = 4,28
out_channel = 1

class CNNModel(nn.Module):

    def __init__(self):
        super(CNNModel, self).__init__()
        self.feature = nn.Sequential()
        
        self.feature.add_module('f_conv1',nn.Conv2d(1, 1, 5))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_conv2',nn.Conv2d(1, 1, 5))
        self.feature.add_module('f_relu2', nn.ReLU(True))
        self.feature.add_module('f_conv3',nn.Conv2d(1, 1, 5))
        self.feature.add_module('f_relu3', nn.ReLU(True))
        

        
     
       


        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(conv_row * conv_col * out_channel, 64))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_fc2', nn.Linear(64, 32))
        self.class_classifier.add_module('c_relu2', nn.ReLU(True))
        self.class_classifier.add_module('c_fc3', nn.Linear(32, 16))
        self.class_classifier.add_module('c_relu3', nn.ReLU(True))
        self.class_classifier.add_module('c_fc4', nn.Linear(16, 4))
        self.class_classifier.add_module('c_softmax', nn.Softmax(dim=1))

        self.domain_classifier = nn.Sequential()
        self.domain_classifier.add_module('d_fc1', nn.Linear(conv_row * conv_col * out_channel, 64))
        
        self.domain_classifier.add_module('d_relu1', nn.ReLU(True))
        self.domain_classifier.add_module('d_fc2', nn.Linear(64, 2))
        # self.domain_classifier.add_module('d_relu2', nn.ReLU(True))
        # self.domain_classifier.add_module('d_fc3', nn.Linear(64, 2))
        self.domain_classifier.add_module('d_softmax', nn.Softmax(dim=1))

    def forward(self, input_data, alpha):
        #input_data = input_data.expand(input_data.data.shape[0], 3, 28, 28)
        # print("I am in forward")
        # print(input_data.data.shape[0])
        input_data = input_data.unsqueeze(1).float()
        feature = self.feature(input_data)
        feature = feature.view(-1, conv_row * conv_col * out_channel)
        reverse_feature = ReverseLayerF.apply(feature, alpha)
        class_output = self.class_classifier(feature)
        domain_output = self.domain_classifier(reverse_feature)

        return class_output, domain_output

    



def test(dataloader):
    #assert dataset_name in ['MNIST', 'mnist_m']

    model_root = ''
    

    cuda = True
    cudnn.benchmark = True
    batch_size = 64
   
    alpha = 0

    """load data"""




    """ test """

    my_net = torch.load(os.path.join(
        model_root, 'mnist_mnistm_model_epoch_current.pth'
    ))
    my_net = my_net.eval()

    if cuda:
        my_net = my_net.cuda()

    len_dataloader = len(dataloader)
    data_target_iter = iter(dataloader)

    i = 0
    n_total = 0
    n_correct = 0

    while i < len_dataloader:

        # test model using target data
        data_target = next(data_target_iter)
        t_img, t_label = data_target

        batch_size = len(t_label)

        if cuda:
            t_img = t_img.cuda()
            t_label = t_label.cuda()

        class_output, _ = my_net(input_data=t_img, alpha=alpha)
        pred = class_output.data.max(1, keepdim=True)[1]
        n_correct += pred.eq(t_label.data.view_as(pred)).cpu().sum()
        n_total += batch_size

        i += 1

    accu = n_correct.data.numpy() * 1.0 / n_total

    return accu

# %%
import random
import os
import sys
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import numpy as np

from torchvision import datasets
from torchvision import transforms




model_root = 'models'
cuda = True
cudnn.benchmark = True
lr = 1e-3


n_epoch = 150

manual_seed = random.randint(1, 10000)
random.seed(manual_seed)
torch.manual_seed(manual_seed)

# load data

dataloader_source = train_loader_lablight_7


dataloader_target = train_loader_sunny_7

my_net = CNNModel()

# setup optimizer

optimizer = optim.Adam(my_net.parameters(), lr=lr)

loss_class = torch.nn.CrossEntropyLoss()
loss_domain = torch.nn.CrossEntropyLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()
    loss_domain = loss_domain.cuda()

for p in my_net.parameters():
    p.requires_grad = True

# training
best_accu_t = 0.0

accList = []
errList = []

for epoch in range(n_epoch):

    len_dataloader = min(len(dataloader_source), len(dataloader_target))
    data_source_iter = iter(dataloader_source)
    data_target_iter = iter(dataloader_target)

    for i in range(len_dataloader):

        p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # training model using source data
        data_source = next(data_source_iter)
        s_img, s_label = data_source
        
        # print('\n')
        # print(s_img.shape)
        # print(s_label)

        my_net.zero_grad()
        batch_size = len(s_label)

        domain_label = torch.ones(batch_size).long()

        if cuda:
            s_img = s_img.cuda()
            s_label = s_label.cuda()
            domain_label = domain_label.cuda()


        class_output, domain_output = my_net(input_data=s_img, alpha=alpha)
        err_s_label = loss_class(class_output, s_label)
        err_s_domain = loss_domain(domain_output, domain_label)

        # training model using target data
        data_target = next(data_target_iter)
        t_img, t_label = data_target
        
        
        # print('\n I am in targert')
        # print(t_img.shape)
        # print(_)

        batch_size = len(t_img)

        domain_label = torch.zeros(batch_size).long()

        if cuda:
            t_img = t_img.cuda()
            t_label = t_label.cuda()
            domain_label = domain_label.cuda()

        _, domain_output = my_net(input_data=t_img, alpha=alpha)
        err_t_domain = loss_domain(domain_output, domain_label)
        err_t_label = loss_class(_,t_label)
        
        err = err_t_domain + err_s_domain + err_s_label #+ err_t_label
      
        err.backward()
       
        
        optimizer.step()
        optimizer.zero_grad()
        errList.append(err)

        sys.stdout.write('\r epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
              % (epoch, i + 1, len_dataloader, err_s_label.data.cpu().numpy(),
                 err_s_domain.data.cpu().numpy(), err_t_domain.data.cpu().item()))
        sys.stdout.flush()
        torch.save(my_net, 'mnist_mnistm_model_epoch_current.pth'.format(model_root))

    print('\n')
    accu_s = test(test_loader_lablight_7)
    print('Accuracy of the %s dataset: %f' % ('source===', accu_s))
    accu_t = test(test_loader_sunny_7)
    print('Accuracy of the %s dataset: %f\n' % ('target', accu_t))
    accList.append([accu_s,accu_t])
    if accu_t > best_accu_t:
        best_accu_s = accu_s
        best_accu_t = accu_t
        torch.save(my_net, 'mnist_mnistm_model_epoch_best.pth'.format(model_root))

print('============ Summary ============= \n')
print('Accuracy of the %s dataset: %f' % ('source', best_accu_s))
print('Accuracy of the %s dataset: %f' % ('target', best_accu_t))
print('Corresponding model was save in ' + model_root + 'mnist_mnistm_model_epoch_best.pth')
# Out:
#  epoch: 0, [iter: 38 / all 38], err_s_label: 1.333915, err_s_domain: 0.728005, err_t_domain: 0.679108
#
# Accuracy of the source=== dataset: 0.301656
# Accuracy of the target dataset: 0.239024
#
#  epoch: 1, [iter: 38 / all 38], err_s_label: 1.315765, err_s_domain: 0.662456, err_t_domain: 0.713995
#
# Accuracy of the source=== dataset: 0.408893
# Accuracy of the target dataset: 0.355122
#
#  epoch: 2, [iter: 38 / all 38], err_s_label: 1.290470, err_s_domain: 0.690563, err_t_domain: 0.657370
#
# Accuracy of the source=== dataset: 0.474281
# Accuracy of the target dataset: 0.366829
#
#  epoch: 3, [iter: 38 / all 38], err_s_label: 1.285677, err_s_domain: 0.685126, err_t_domain: 0.739785
#
# Accuracy of the source=== dataset: 0.485615
# Accuracy of the target dataset: 0.408780
#
#  epoch: 4, [iter: 38 / all 38], err_s_label: 1.214060, err_s_domain: 0.702571, err_t_domain: 0.664303
#
# Accuracy of the source=== dataset: 0.532694
# Accuracy of the target dataset: 0.410732
#
#  epoch: 5, [iter: 38 / all 38], err_s_label: 1.199540, err_s_domain: 0.693592, err_t_domain: 0.630049
#
# Accuracy of the source=== dataset: 0.520488
# Accuracy of the target dataset: 0.404878
#
#  epoch: 6, [iter: 38 / all 38], err_s_label: 1.169204, err_s_domain: 0.642093, err_t_domain: 0.694667
#
# Accuracy of the source=== dataset: 0.541412
# Accuracy of the target dataset: 0.382439
#
#  epoch: 7, [iter: 38 / all 38], err_s_label: 1.145231, err_s_domain: 0.664061, err_t_domain: 0.680937
#
# Accuracy of the source=== dataset: 0.559721
# Accuracy of the target dataset: 0.409756
#
#  epoch: 8, [iter: 38 / all 38], err_s_label: 1.117843, err_s_domain: 0.688293, err_t_domain: 0.645035
#
# Accuracy of the source=== dataset: 0.581517
# Accuracy of the target dataset: 0.411707
#
#  epoch: 9, [iter: 38 / all 38], err_s_label: 1.106920, err_s_domain: 0.688499, err_t_domain: 0.650436
#
# Accuracy of the source=== dataset: 0.598954
# Accuracy of the target dataset: 0.397073
#
#  epoch: 10, [iter: 38 / all 38], err_s_label: 1.100773, err_s_domain: 0.734875, err_t_domain: 0.633351
#
# Accuracy of the source=== dataset: 0.637315
# Accuracy of the target dataset: 0.355122
#
#  epoch: 11, [iter: 38 / all 38], err_s_label: 1.076321, err_s_domain: 0.697931, err_t_domain: 0.690911
#
# Accuracy of the source=== dataset: 0.658239
# Accuracy of the target dataset: 0.310244
#
#  epoch: 12, [iter: 38 / all 38], err_s_label: 1.028244, err_s_domain: 0.688789, err_t_domain: 0.667756
#
# Accuracy of the source=== dataset: 0.691369
# Accuracy of the target dataset: 0.290732
#
#  epoch: 13, [iter: 38 / all 38], err_s_label: 1.021427, err_s_domain: 0.652341, err_t_domain: 0.701207
#
# Accuracy of the source=== dataset: 0.710549
# Accuracy of the target dataset: 0.293659
#
#  epoch: 14, [iter: 38 / all 38], err_s_label: 1.008291, err_s_domain: 0.627520, err_t_domain: 0.714268
#
# Accuracy of the source=== dataset: 0.733217
# Accuracy of the target dataset: 0.287805
#
#  epoch: 15, [iter: 38 / all 38], err_s_label: 0.995261, err_s_domain: 0.637773, err_t_domain: 0.678669
#
# Accuracy of the source=== dataset: 0.739320
# Accuracy of the target dataset: 0.280000
#
#  epoch: 16, [iter: 38 / all 38], err_s_label: 0.990602, err_s_domain: 0.642925, err_t_domain: 0.644507
#
# Accuracy of the source=== dataset: 0.721883
# Accuracy of the target dataset: 0.282927
#
#  epoch: 17, [iter: 38 / all 38], err_s_label: 0.978474, err_s_domain: 0.640197, err_t_domain: 0.634428
#
# Accuracy of the source=== dataset: 0.758500
# Accuracy of the target dataset: 0.274146
#
#  epoch: 18, [iter: 38 / all 38], err_s_label: 0.980419, err_s_domain: 0.650924, err_t_domain: 0.603272
#
# Accuracy of the source=== dataset: 0.757629
# Accuracy of the target dataset: 0.261463
#
#  epoch: 19, [iter: 38 / all 38], err_s_label: 0.958964, err_s_domain: 0.649160, err_t_domain: 0.585946
#
# Accuracy of the source=== dataset: 0.765475
# Accuracy of the target dataset: 0.258537
#
#  epoch: 20, [iter: 38 / all 38], err_s_label: 0.971599, err_s_domain: 0.641080, err_t_domain: 0.586527
#
# Accuracy of the source=== dataset: 0.757629
# Accuracy of the target dataset: 0.271220
#
#  epoch: 21, [iter: 38 / all 38], err_s_label: 0.972640, err_s_domain: 0.648299, err_t_domain: 0.577136
#
# Accuracy of the source=== dataset: 0.773322
# Accuracy of the target dataset: 0.264390
#
#  epoch: 22, [iter: 38 / all 38], err_s_label: 0.943426, err_s_domain: 0.637100, err_t_domain: 0.567337
#
# Accuracy of the source=== dataset: 0.784656
# Accuracy of the target dataset: 0.266341
#
#  epoch: 23, [iter: 38 / all 38], err_s_label: 0.942476, err_s_domain: 0.643875, err_t_domain: 0.548136
#
# Accuracy of the source=== dataset: 0.761988
# Accuracy of the target dataset: 0.247805
#
#  epoch: 24, [iter: 38 / all 38], err_s_label: 0.963666, err_s_domain: 0.616454, err_t_domain: 0.578423
#
# Accuracy of the source=== dataset: 0.782912
# Accuracy of the target dataset: 0.249756
#
#  epoch: 25, [iter: 38 / all 38], err_s_label: 0.967546, err_s_domain: 0.607471, err_t_domain: 0.575232
#
# Accuracy of the source=== dataset: 0.789015
# Accuracy of the target dataset: 0.262439
#
#  epoch: 26, [iter: 38 / all 38], err_s_label: 0.964727, err_s_domain: 0.596570, err_t_domain: 0.587116
#
# Accuracy of the source=== dataset: 0.781168
# Accuracy of the target dataset: 0.258537
#
#  epoch: 27, [iter: 38 / all 38], err_s_label: 0.991903, err_s_domain: 0.602550, err_t_domain: 0.593452
#
# Accuracy of the source=== dataset: 0.752398
# Accuracy of the target dataset: 0.273171
#
#  epoch: 28, [iter: 38 / all 38], err_s_label: 0.973010, err_s_domain: 0.587987, err_t_domain: 0.575862
#
# Accuracy of the source=== dataset: 0.778553
# Accuracy of the target dataset: 0.265366
#
#  epoch: 29, [iter: 38 / all 38], err_s_label: 0.988432, err_s_domain: 0.626153, err_t_domain: 0.530895
#
# Accuracy of the source=== dataset: 0.767219
# Accuracy of the target dataset: 0.260488
#
#  epoch: 30, [iter: 38 / all 38], err_s_label: 0.962081, err_s_domain: 0.620179, err_t_domain: 0.526993
#
# Accuracy of the source=== dataset: 0.777681
# Accuracy of the target dataset: 0.262439
#
#  epoch: 31, [iter: 38 / all 38], err_s_label: 0.974256, err_s_domain: 0.652731, err_t_domain: 0.492040
#
# Accuracy of the source=== dataset: 0.783784
# Accuracy of the target dataset: 0.269268
#
#  epoch: 32, [iter: 38 / all 38], err_s_label: 0.967150, err_s_domain: 0.642443, err_t_domain: 0.491837
#
# Accuracy of the source=== dataset: 0.806452
# Accuracy of the target dataset: 0.263415
#
#  epoch: 33, [iter: 38 / all 38], err_s_label: 0.962292, err_s_domain: 0.644474, err_t_domain: 0.499691
#
# Accuracy of the source=== dataset: 0.792502
# Accuracy of the target dataset: 0.274146
#
#  epoch: 34, [iter: 38 / all 38], err_s_label: 0.959539, err_s_domain: 0.634928, err_t_domain: 0.512345
#
# Accuracy of the source=== dataset: 0.795990
# Accuracy of the target dataset: 0.264390
#
#  epoch: 35, [iter: 38 / all 38], err_s_label: 0.989252, err_s_domain: 0.657840, err_t_domain: 0.552058
#
# Accuracy of the source=== dataset: 0.758500
# Accuracy of the target dataset: 0.283902
#
#  epoch: 36, [iter: 38 / all 38], err_s_label: 1.014421, err_s_domain: 0.726037, err_t_domain: 0.587634
#
# Accuracy of the source=== dataset: 0.763731
# Accuracy of the target dataset: 0.259512
#
#  epoch: 37, [iter: 38 / all 38], err_s_label: 1.009683, err_s_domain: 0.703892, err_t_domain: 0.567902
#
# Accuracy of the source=== dataset: 0.760244
# Accuracy of the target dataset: 0.271220
#
#  epoch: 38, [iter: 38 / all 38], err_s_label: 1.006309, err_s_domain: 0.734344, err_t_domain: 0.549493
#
# Accuracy of the source=== dataset: 0.782040
# Accuracy of the target dataset: 0.272195
#
#  epoch: 39, [iter: 38 / all 38], err_s_label: 0.994863, err_s_domain: 0.710719, err_t_domain: 0.561665
#
# Accuracy of the source=== dataset: 0.784656
# Accuracy of the target dataset: 0.263415
#
#  epoch: 40, [iter: 38 / all 38], err_s_label: 0.947687, err_s_domain: 0.708297, err_t_domain: 0.554706
#
# Accuracy of the source=== dataset: 0.795118
# Accuracy of the target dataset: 0.282927
#
#  epoch: 41, [iter: 38 / all 38], err_s_label: 0.981435, err_s_domain: 0.712906, err_t_domain: 0.567391
#
# Accuracy of the source=== dataset: 0.797733
# Accuracy of the target dataset: 0.281951
#
#  epoch: 42, [iter: 38 / all 38], err_s_label: 0.943510, err_s_domain: 0.714512, err_t_domain: 0.562313
#
# Accuracy of the source=== dataset: 0.801221
# Accuracy of the target dataset: 0.281951
#
#  epoch: 43, [iter: 38 / all 38], err_s_label: 0.954185, err_s_domain: 0.716562, err_t_domain: 0.559726
#
# Accuracy of the source=== dataset: 0.809067
# Accuracy of the target dataset: 0.280000
#
#  epoch: 44, [iter: 38 / all 38], err_s_label: 0.946480, err_s_domain: 0.710515, err_t_domain: 0.579542
#
# Accuracy of the source=== dataset: 0.802964
# Accuracy of the target dataset: 0.288780
#
#  epoch: 45, [iter: 38 / all 38], err_s_label: 0.938222, err_s_domain: 0.722095, err_t_domain: 0.555987
#
# Accuracy of the source=== dataset: 0.807323
# Accuracy of the target dataset: 0.291707
#
#  epoch: 46, [iter: 38 / all 38], err_s_label: 0.941027, err_s_domain: 0.706764, err_t_domain: 0.581350
#
# Accuracy of the source=== dataset: 0.800349
# Accuracy of the target dataset: 0.289756
#
#  epoch: 47, [iter: 38 / all 38], err_s_label: 0.937612, err_s_domain: 0.709941, err_t_domain: 0.563323
#
# Accuracy of the source=== dataset: 0.806452
# Accuracy of the target dataset: 0.296585
#
#  epoch: 48, [iter: 38 / all 38], err_s_label: 0.931604, err_s_domain: 0.688557, err_t_domain: 0.564804
#
# Accuracy of the source=== dataset: 0.814298
# Accuracy of the target dataset: 0.284878
#
#  epoch: 49, [iter: 38 / all 38], err_s_label: 0.941490, err_s_domain: 0.676042, err_t_domain: 0.576343
#
# Accuracy of the source=== dataset: 0.822145
# Accuracy of the target dataset: 0.279024
#
#  epoch: 50, [iter: 38 / all 38], err_s_label: 0.957754, err_s_domain: 0.675726, err_t_domain: 0.570156
#
# Accuracy of the source=== dataset: 0.808195
# Accuracy of the target dataset: 0.280976
#
#  epoch: 51, [iter: 38 / all 38], err_s_label: 0.947390, err_s_domain: 0.662163, err_t_domain: 0.577916
#
# Accuracy of the source=== dataset: 0.822145
# Accuracy of the target dataset: 0.271220
#
#  epoch: 52, [iter: 38 / all 38], err_s_label: 0.933595, err_s_domain: 0.664076, err_t_domain: 0.577801
#
# Accuracy of the source=== dataset: 0.815170
# Accuracy of the target dataset: 0.285854
#
#  epoch: 53, [iter: 38 / all 38], err_s_label: 0.919673, err_s_domain: 0.655354, err_t_domain: 0.573458
#
# Accuracy of the source=== dataset: 0.821273
# Accuracy of the target dataset: 0.265366
#
#  epoch: 54, [iter: 38 / all 38], err_s_label: 0.920927, err_s_domain: 0.655933, err_t_domain: 0.567347
#
# Accuracy of the source=== dataset: 0.826504
# Accuracy of the target dataset: 0.262439
#
#  epoch: 55, [iter: 38 / all 38], err_s_label: 0.909189, err_s_domain: 0.655846, err_t_domain: 0.569627
#
# Accuracy of the source=== dataset: 0.825632
# Accuracy of the target dataset: 0.266341
#
#  epoch: 56, [iter: 38 / all 38], err_s_label: 0.910815, err_s_domain: 0.662479, err_t_domain: 0.574496
#
# Accuracy of the source=== dataset: 0.822145
# Accuracy of the target dataset: 0.264390
#
#  epoch: 57, [iter: 38 / all 38], err_s_label: 0.916856, err_s_domain: 0.663399, err_t_domain: 0.578423
#
# Accuracy of the source=== dataset: 0.823017
# Accuracy of the target dataset: 0.273171
#
#  epoch: 58, [iter: 38 / all 38], err_s_label: 0.928287, err_s_domain: 0.675181, err_t_domain: 0.585425
#
# Accuracy of the source=== dataset: 0.802092
# Accuracy of the target dataset: 0.258537
#
#  epoch: 59, [iter: 38 / all 38], err_s_label: 0.956193, err_s_domain: 0.676740, err_t_domain: 0.593233
#
# Accuracy of the source=== dataset: 0.823888
# Accuracy of the target dataset: 0.259512
#
#  epoch: 60, [iter: 38 / all 38], err_s_label: 0.942723, err_s_domain: 0.658213, err_t_domain: 0.604257
#
# Accuracy of the source=== dataset: 0.825632
# Accuracy of the target dataset: 0.259512
#
#  epoch: 61, [iter: 38 / all 38], err_s_label: 0.927239, err_s_domain: 0.677955, err_t_domain: 0.589494
#
# Accuracy of the source=== dataset: 0.827376
# Accuracy of the target dataset: 0.263415
#
#  epoch: 62, [iter: 38 / all 38], err_s_label: 0.933595, err_s_domain: 0.653202, err_t_domain: 0.599631
#
# Accuracy of the source=== dataset: 0.823017
# Accuracy of the target dataset: 0.268293
#
#  epoch: 63, [iter: 38 / all 38], err_s_label: 0.938400, err_s_domain: 0.676888, err_t_domain: 0.585250
#
# Accuracy of the source=== dataset: 0.834350
# Accuracy of the target dataset: 0.274146
#
#  epoch: 64, [iter: 38 / all 38], err_s_label: 0.964669, err_s_domain: 0.651688, err_t_domain: 0.616173
#
# Accuracy of the source=== dataset: 0.826504
# Accuracy of the target dataset: 0.280000
#
#  epoch: 65, [iter: 38 / all 38], err_s_label: 0.966152, err_s_domain: 0.665798, err_t_domain: 0.594704
#
# Accuracy of the source=== dataset: 0.834350
# Accuracy of the target dataset: 0.289756
#
#  epoch: 66, [iter: 38 / all 38], err_s_label: 0.943995, err_s_domain: 0.652253, err_t_domain: 0.610781
#
# Accuracy of the source=== dataset: 0.837838
# Accuracy of the target dataset: 0.291707
#
#  epoch: 67, [iter: 38 / all 38], err_s_label: 0.969459, err_s_domain: 0.658507, err_t_domain: 0.605079
#
# Accuracy of the source=== dataset: 0.829119
# Accuracy of the target dataset: 0.285854
#
#  epoch: 68, [iter: 38 / all 38], err_s_label: 0.940474, err_s_domain: 0.655894, err_t_domain: 0.601300
#
# Accuracy of the source=== dataset: 0.832607
# Accuracy of the target dataset: 0.278049
#
#  epoch: 69, [iter: 38 / all 38], err_s_label: 0.933267, err_s_domain: 0.655593, err_t_domain: 0.592026
#
# Accuracy of the source=== dataset: 0.836094
# Accuracy of the target dataset: 0.277073
#
#  epoch: 70, [iter: 38 / all 38], err_s_label: 0.949072, err_s_domain: 0.641478, err_t_domain: 0.609206
#
# Accuracy of the source=== dataset: 0.840453
# Accuracy of the target dataset: 0.280000
#
#  epoch: 71, [iter: 38 / all 38], err_s_label: 0.965780, err_s_domain: 0.662344, err_t_domain: 0.594920
#
# Accuracy of the source=== dataset: 0.836094
# Accuracy of the target dataset: 0.274146
#
#  epoch: 72, [iter: 38 / all 38], err_s_label: 0.977609, err_s_domain: 0.666068, err_t_domain: 0.603658
#
# Accuracy of the source=== dataset: 0.840453
# Accuracy of the target dataset: 0.262439
#
#  epoch: 73, [iter: 38 / all 38], err_s_label: 0.898796, err_s_domain: 0.651291, err_t_domain: 0.594848
#
# Accuracy of the source=== dataset: 0.819529
# Accuracy of the target dataset: 0.245854
#
#  epoch: 74, [iter: 38 / all 38], err_s_label: 0.889828, err_s_domain: 0.649468, err_t_domain: 0.595908
#
# Accuracy of the source=== dataset: 0.838710
# Accuracy of the target dataset: 0.249756
#
#  epoch: 75, [iter: 38 / all 38], err_s_label: 0.892327, err_s_domain: 0.657183, err_t_domain: 0.591818
#
# Accuracy of the source=== dataset: 0.850915
# Accuracy of the target dataset: 0.256585
#
#  epoch: 76, [iter: 38 / all 38], err_s_label: 0.882153, err_s_domain: 0.664364, err_t_domain: 0.600726
#
# Accuracy of the source=== dataset: 0.809067
# Accuracy of the target dataset: 0.272195
#
#  epoch: 77, [iter: 38 / all 38], err_s_label: 0.869058, err_s_domain: 0.655381, err_t_domain: 0.586171
#
# Accuracy of the source=== dataset: 0.800349
# Accuracy of the target dataset: 0.267317
#
#  epoch: 78, [iter: 38 / all 38], err_s_label: 0.886827, err_s_domain: 0.659991, err_t_domain: 0.602843
#
# Accuracy of the source=== dataset: 0.828248
# Accuracy of the target dataset: 0.260488
#
#  epoch: 79, [iter: 38 / all 38], err_s_label: 0.874505, err_s_domain: 0.654012, err_t_domain: 0.610751
#
# Accuracy of the source=== dataset: 0.823017
# Accuracy of the target dataset: 0.275122
#
#  epoch: 80, [iter: 38 / all 38], err_s_label: 0.904130, err_s_domain: 0.653155, err_t_domain: 0.620850
#
# Accuracy of the source=== dataset: 0.851787
# Accuracy of the target dataset: 0.275122
#
#  epoch: 81, [iter: 38 / all 38], err_s_label: 0.935177, err_s_domain: 0.668002, err_t_domain: 0.646751
#
# Accuracy of the source=== dataset: 0.829991
# Accuracy of the target dataset: 0.262439
#
#  epoch: 82, [iter: 38 / all 38], err_s_label: 0.882473, err_s_domain: 0.669194, err_t_domain: 0.603799
#
# Accuracy of the source=== dataset: 0.748910
# Accuracy of the target dataset: 0.277073
#
#  epoch: 83, [iter: 38 / all 38], err_s_label: 0.906723, err_s_domain: 0.655718, err_t_domain: 0.589277
#
# Accuracy of the source=== dataset: 0.854403
# Accuracy of the target dataset: 0.256585
#
#  epoch: 84, [iter: 38 / all 38], err_s_label: 0.903540, err_s_domain: 0.663789, err_t_domain: 0.614975
#
# Accuracy of the source=== dataset: 0.833479
# Accuracy of the target dataset: 0.273171
#
#  epoch: 85, [iter: 38 / all 38], err_s_label: 0.877680, err_s_domain: 0.663370, err_t_domain: 0.624066
#
# Accuracy of the source=== dataset: 0.843941
# Accuracy of the target dataset: 0.289756
#
#  epoch: 86, [iter: 38 / all 38], err_s_label: 0.913448, err_s_domain: 0.666346, err_t_domain: 0.647543
#
# Accuracy of the source=== dataset: 0.842197
# Accuracy of the target dataset: 0.282927
#
#  epoch: 87, [iter: 38 / all 38], err_s_label: 0.875330, err_s_domain: 0.657620, err_t_domain: 0.614886
#
# Accuracy of the source=== dataset: 0.846556
# Accuracy of the target dataset: 0.280000
#
#  epoch: 88, [iter: 38 / all 38], err_s_label: 0.873176, err_s_domain: 0.657250, err_t_domain: 0.603637
#
# Accuracy of the source=== dataset: 0.830863
# Accuracy of the target dataset: 0.296585
#
#  epoch: 89, [iter: 38 / all 38], err_s_label: 0.976565, err_s_domain: 0.646743, err_t_domain: 0.644707
#
# Accuracy of the source=== dataset: 0.851787
# Accuracy of the target dataset: 0.276098
#
#  epoch: 90, [iter: 38 / all 38], err_s_label: 0.899676, err_s_domain: 0.661323, err_t_domain: 0.607112
#
# Accuracy of the source=== dataset: 0.833479
# Accuracy of the target dataset: 0.293659
#
#  epoch: 91, [iter: 38 / all 38], err_s_label: 0.888247, err_s_domain: 0.672021, err_t_domain: 0.604595
#
# Accuracy of the source=== dataset: 0.824760
# Accuracy of the target dataset: 0.292683
#
#  epoch: 92, [iter: 38 / all 38], err_s_label: 0.918799, err_s_domain: 0.685460, err_t_domain: 0.594669
#
# Accuracy of the source=== dataset: 0.845684
# Accuracy of the target dataset: 0.300488
#
#  epoch: 93, [iter: 38 / all 38], err_s_label: 0.872352, err_s_domain: 0.691069, err_t_domain: 0.639381
#
# Accuracy of the source=== dataset: 0.823888
# Accuracy of the target dataset: 0.356098
#
#  epoch: 94, [iter: 38 / all 38], err_s_label: 1.012636, err_s_domain: 0.696858, err_t_domain: 0.616569
#
# Accuracy of the source=== dataset: 0.803836
# Accuracy of the target dataset: 0.341463
#
#  epoch: 95, [iter: 38 / all 38], err_s_label: 0.862544, err_s_domain: 0.699256, err_t_domain: 0.629291
#
# Accuracy of the source=== dataset: 0.831735
# Accuracy of the target dataset: 0.341463
#
#  epoch: 96, [iter: 38 / all 38], err_s_label: 0.847080, err_s_domain: 0.701872, err_t_domain: 0.620620
#
# Accuracy of the source=== dataset: 0.833479
# Accuracy of the target dataset: 0.320000
#
#  epoch: 97, [iter: 38 / all 38], err_s_label: 0.847989, err_s_domain: 0.683932, err_t_domain: 0.609572
#
# Accuracy of the source=== dataset: 0.824760
# Accuracy of the target dataset: 0.303415
#
#  epoch: 98, [iter: 38 / all 38], err_s_label: 0.848345, err_s_domain: 0.681166, err_t_domain: 0.615200
#
# Accuracy of the source=== dataset: 0.836966
# Accuracy of the target dataset: 0.304390
#
#  epoch: 99, [iter: 38 / all 38], err_s_label: 0.833864, err_s_domain: 0.666216, err_t_domain: 0.614999
#
# Accuracy of the source=== dataset: 0.843941
# Accuracy of the target dataset: 0.289756
#
#  epoch: 100, [iter: 38 / all 38], err_s_label: 0.839043, err_s_domain: 0.665236, err_t_domain: 0.608629
#
# Accuracy of the source=== dataset: 0.830863
# Accuracy of the target dataset: 0.285854
#
#  epoch: 101, [iter: 38 / all 38], err_s_label: 0.863702, err_s_domain: 0.662537, err_t_domain: 0.614960
#
# Accuracy of the source=== dataset: 0.838710
# Accuracy of the target dataset: 0.305366
#
#  epoch: 102, [iter: 38 / all 38], err_s_label: 0.830185, err_s_domain: 0.657098, err_t_domain: 0.621075
#
# Accuracy of the source=== dataset: 0.844813
# Accuracy of the target dataset: 0.285854
#
#  epoch: 103, [iter: 38 / all 38], err_s_label: 0.832754, err_s_domain: 0.666552, err_t_domain: 0.628356
#
# Accuracy of the source=== dataset: 0.829991
# Accuracy of the target dataset: 0.277073
#
#  epoch: 104, [iter: 38 / all 38], err_s_label: 0.841021, err_s_domain: 0.669786, err_t_domain: 0.633553
#
# Accuracy of the source=== dataset: 0.816914
# Accuracy of the target dataset: 0.289756
#
#  epoch: 105, [iter: 38 / all 38], err_s_label: 0.849569, err_s_domain: 0.657941, err_t_domain: 0.627290
#
# Accuracy of the source=== dataset: 0.821273
# Accuracy of the target dataset: 0.292683
#
#  epoch: 106, [iter: 38 / all 38], err_s_label: 0.855111, err_s_domain: 0.676928, err_t_domain: 0.607501
#
# Accuracy of the source=== dataset: 0.839582
# Accuracy of the target dataset: 0.287805
#
#  epoch: 107, [iter: 38 / all 38], err_s_label: 0.847503, err_s_domain: 0.665576, err_t_domain: 0.604911
#
# Accuracy of the source=== dataset: 0.842197
# Accuracy of the target dataset: 0.300488
#
#  epoch: 108, [iter: 38 / all 38], err_s_label: 0.815351, err_s_domain: 0.654813, err_t_domain: 0.611155
#
# Accuracy of the source=== dataset: 0.846556
# Accuracy of the target dataset: 0.287805
#
#  epoch: 109, [iter: 38 / all 38], err_s_label: 0.825683, err_s_domain: 0.652576, err_t_domain: 0.608336
#
# Accuracy of the source=== dataset: 0.850044
# Accuracy of the target dataset: 0.285854
#
#  epoch: 110, [iter: 38 / all 38], err_s_label: 0.819661, err_s_domain: 0.652304, err_t_domain: 0.618710
#
# Accuracy of the source=== dataset: 0.845684
# Accuracy of the target dataset: 0.290732
#
#  epoch: 111, [iter: 38 / all 38], err_s_label: 0.852730, err_s_domain: 0.653012, err_t_domain: 0.605536
#
# Accuracy of the source=== dataset: 0.843941
# Accuracy of the target dataset: 0.302439
#
#  epoch: 112, [iter: 38 / all 38], err_s_label: 0.860752, err_s_domain: 0.648848, err_t_domain: 0.625261
#
# Accuracy of the source=== dataset: 0.840453
# Accuracy of the target dataset: 0.284878
#
#  epoch: 113, [iter: 38 / all 38], err_s_label: 0.840611, err_s_domain: 0.651644, err_t_domain: 0.649070
#
# Accuracy of the source=== dataset: 0.839582
# Accuracy of the target dataset: 0.303415
#
#  epoch: 114, [iter: 38 / all 38], err_s_label: 0.896151, err_s_domain: 0.646283, err_t_domain: 0.635405
#
# Accuracy of the source=== dataset: 0.830863
# Accuracy of the target dataset: 0.288780
#
#  epoch: 115, [iter: 38 / all 38], err_s_label: 0.842016, err_s_domain: 0.636008, err_t_domain: 0.644437
#
# Accuracy of the source=== dataset: 0.850044
# Accuracy of the target dataset: 0.286829
#
#  epoch: 116, [iter: 38 / all 38], err_s_label: 0.848089, err_s_domain: 0.645653, err_t_domain: 0.628620
#
# Accuracy of the source=== dataset: 0.852659
# Accuracy of the target dataset: 0.289756
#
#  epoch: 117, [iter: 38 / all 38], err_s_label: 0.840658, err_s_domain: 0.646593, err_t_domain: 0.600894
#
# Accuracy of the source=== dataset: 0.832607
# Accuracy of the target dataset: 0.294634
#
#  epoch: 118, [iter: 38 / all 38], err_s_label: 0.863292, err_s_domain: 0.656632, err_t_domain: 0.581234
#
# Accuracy of the source=== dataset: 0.838710
# Accuracy of the target dataset: 0.295610
#
#  epoch: 119, [iter: 38 / all 38], err_s_label: 0.847784, err_s_domain: 0.650407, err_t_domain: 0.595711
#
# Accuracy of the source=== dataset: 0.840453
# Accuracy of the target dataset: 0.288780
#
#  epoch: 120, [iter: 38 / all 38], err_s_label: 0.894484, err_s_domain: 0.650349, err_t_domain: 0.595872
#
# Accuracy of the source=== dataset: 0.844813
# Accuracy of the target dataset: 0.302439
#
#  epoch: 121, [iter: 38 / all 38], err_s_label: 0.846679, err_s_domain: 0.638149, err_t_domain: 0.599158
#
# Accuracy of the source=== dataset: 0.844813
# Accuracy of the target dataset: 0.302439
#
#  epoch: 122, [iter: 38 / all 38], err_s_label: 0.829873, err_s_domain: 0.636233, err_t_domain: 0.602516
#
# Accuracy of the source=== dataset: 0.848300
# Accuracy of the target dataset: 0.303415
#
#  epoch: 123, [iter: 38 / all 38], err_s_label: 0.848004, err_s_domain: 0.626640, err_t_domain: 0.614587
#
# Accuracy of the source=== dataset: 0.851787
# Accuracy of the target dataset: 0.302439
#
#  epoch: 124, [iter: 38 / all 38], err_s_label: 0.830599, err_s_domain: 0.643135, err_t_domain: 0.610052
#
# Accuracy of the source=== dataset: 0.843941
# Accuracy of the target dataset: 0.286829
#
#  epoch: 125, [iter: 38 / all 38], err_s_label: 0.826475, err_s_domain: 0.632437, err_t_domain: 0.619045
#
# Accuracy of the source=== dataset: 0.843941
# Accuracy of the target dataset: 0.306341
#
#  epoch: 126, [iter: 38 / all 38], err_s_label: 0.843783, err_s_domain: 0.634634, err_t_domain: 0.630552
#
# Accuracy of the source=== dataset: 0.842197
# Accuracy of the target dataset: 0.299512
#
#  epoch: 127, [iter: 38 / all 38], err_s_label: 0.817852, err_s_domain: 0.631707, err_t_domain: 0.630732
#
# Accuracy of the source=== dataset: 0.842197
# Accuracy of the target dataset: 0.312195
#
#  epoch: 128, [iter: 38 / all 38], err_s_label: 0.858326, err_s_domain: 0.648043, err_t_domain: 0.654613
#
# Accuracy of the source=== dataset: 0.832607
# Accuracy of the target dataset: 0.279024
#
#  epoch: 129, [iter: 38 / all 38], err_s_label: 0.912623, err_s_domain: 0.666381, err_t_domain: 0.653024
#
# Accuracy of the source=== dataset: 0.823888
# Accuracy of the target dataset: 0.275122
#
#  epoch: 130, [iter: 38 / all 38], err_s_label: 0.918999, err_s_domain: 0.657203, err_t_domain: 0.641784
#
# Accuracy of the source=== dataset: 0.819529
# Accuracy of the target dataset: 0.284878
#
#  epoch: 131, [iter: 38 / all 38], err_s_label: 0.854005, err_s_domain: 0.703625, err_t_domain: 0.658503
#
# Accuracy of the source=== dataset: 0.815170
# Accuracy of the target dataset: 0.310244
#
#  epoch: 132, [iter: 38 / all 38], err_s_label: 0.845726, err_s_domain: 0.640256, err_t_domain: 0.622782
#
# Accuracy of the source=== dataset: 0.827376
# Accuracy of the target dataset: 0.290732
#
#  epoch: 133, [iter: 38 / all 38], err_s_label: 0.805543, err_s_domain: 0.657505, err_t_domain: 0.599421
#
# Accuracy of the source=== dataset: 0.856146
# Accuracy of the target dataset: 0.297561
#
#  epoch: 134, [iter: 38 / all 38], err_s_label: 0.808270, err_s_domain: 0.646138, err_t_domain: 0.598083
#
# Accuracy of the source=== dataset: 0.844813
# Accuracy of the target dataset: 0.295610
#
#  epoch: 135, [iter: 38 / all 38], err_s_label: 0.817009, err_s_domain: 0.652659, err_t_domain: 0.604375
#
# Accuracy of the source=== dataset: 0.827376
# Accuracy of the target dataset: 0.291707
#
#  epoch: 136, [iter: 38 / all 38], err_s_label: 0.920035, err_s_domain: 0.658462, err_t_domain: 0.651099
#
# Accuracy of the source=== dataset: 0.807323
# Accuracy of the target dataset: 0.306341
#
#  epoch: 137, [iter: 38 / all 38], err_s_label: 0.857555, err_s_domain: 0.654086, err_t_domain: 0.613275
#
# Accuracy of the source=== dataset: 0.805580
# Accuracy of the target dataset: 0.292683
#
#  epoch: 138, [iter: 38 / all 38], err_s_label: 0.824439, err_s_domain: 0.657646, err_t_domain: 0.602670
#
# Accuracy of the source=== dataset: 0.851787
# Accuracy of the target dataset: 0.303415
#
#  epoch: 139, [iter: 38 / all 38], err_s_label: 0.798919, err_s_domain: 0.640094, err_t_domain: 0.611427
#
# Accuracy of the source=== dataset: 0.840453
# Accuracy of the target dataset: 0.296585
#
#  epoch: 140, [iter: 38 / all 38], err_s_label: 0.830200, err_s_domain: 0.660968, err_t_domain: 0.602708
#
# Accuracy of the source=== dataset: 0.831735
# Accuracy of the target dataset: 0.281951
#
#  epoch: 141, [iter: 38 / all 38], err_s_label: 0.800348, err_s_domain: 0.636957, err_t_domain: 0.617963
#
# Accuracy of the source=== dataset: 0.851787
# Accuracy of the target dataset: 0.291707
#
#  epoch: 142, [iter: 38 / all 38], err_s_label: 0.825685, err_s_domain: 0.651531, err_t_domain: 0.596216
#
# Accuracy of the source=== dataset: 0.845684
# Accuracy of the target dataset: 0.288780
#
#  epoch: 143, [iter: 38 / all 38], err_s_label: 0.802221, err_s_domain: 0.641728, err_t_domain: 0.604672
#
# Accuracy of the source=== dataset: 0.852659
# Accuracy of the target dataset: 0.287805
#
#  epoch: 144, [iter: 38 / all 38], err_s_label: 0.795421, err_s_domain: 0.636498, err_t_domain: 0.613384
#
# Accuracy of the source=== dataset: 0.860506
# Accuracy of the target dataset: 0.290732
#
#  epoch: 145, [iter: 38 / all 38], err_s_label: 0.815371, err_s_domain: 0.644757, err_t_domain: 0.612204
#
# Accuracy of the source=== dataset: 0.837838
# Accuracy of the target dataset: 0.317073
#
#  epoch: 146, [iter: 38 / all 38], err_s_label: 0.826063, err_s_domain: 0.633546, err_t_domain: 0.588887
#
# Accuracy of the source=== dataset: 0.834350
# Accuracy of the target dataset: 0.308293
#
#  epoch: 147, [iter: 38 / all 38], err_s_label: 0.837219, err_s_domain: 0.666688, err_t_domain: 0.586174
#
# Accuracy of the source=== dataset: 0.839582
# Accuracy of the target dataset: 0.289756
#
#  epoch: 148, [iter: 38 / all 38], err_s_label: 0.817616, err_s_domain: 0.637751, err_t_domain: 0.598735
#
# Accuracy of the source=== dataset: 0.840453
# Accuracy of the target dataset: 0.323902
#
#  epoch: 149, [iter: 38 / all 38], err_s_label: 0.806479, err_s_domain: 0.651820, err_t_domain: 0.595975
#
# Accuracy of the source=== dataset: 0.850044
# Accuracy of the target dataset: 0.326829
#
# ============ Summary =============
#
# Accuracy of the source dataset: 0.581517
# Accuracy of the target dataset: 0.411707
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth

# %%
from PIL import Image

# Load RGB image
img = Image.open('gan/generated_000.jpg')

# Convert to grayscale
gray_img = img.convert('L')

# Resize to 28x28
resized_img = gray_img.resize((28, 28))

# Display the resized image
resized_img.show()
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x7F8B9AFF8BE0>
