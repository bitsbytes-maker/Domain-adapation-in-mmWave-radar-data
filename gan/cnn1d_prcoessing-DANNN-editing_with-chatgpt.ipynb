# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from scipy.spatial.distance import cdist

import random
import os
import sys
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import numpy as np

from torchvision import datasets
from torchvision import transforms

# %%
import pandas as pd
import numpy as np
import random
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
tform1 = StandardScaler()
tform=transforms.Compose([
                           transforms.ToTensor()])
def fileFeedforGNN(name):

  data = pd.read_table(name)

  

  y = data.iloc[:,-3].values
  
  
  print(np.unique(y))


  graphList = []
  


    
  #num_objects	r_std	r_var	r_mean	r_min	r_max	snr_std	snr_var	snr_mean	snr_min	snr_max	noise_std	noise_var	noise_mean	noise_min	noise_max	obj	environment	
  X_array = data.iloc[:, 0:16].values

  X_array = tform1.fit_transform(X_array)
  

  addList_bot, addList_clothes, addList_plastics, addList_steel  = [],[],[],[]
    
  for i in range(len(X_array)):
    intarray = X_array[i]
    if(y[i] =='bot'):
      addList_bot.append(intarray)
    elif (y[i] == 'clothes'):
      addList_clothes.append(intarray)
    elif (y[i] == 'plastic'):
      addList_plastics.append(intarray)
    elif (y[i] == 'steel'):
      addList_steel.append(intarray)
  
  len_img = 40
  for i in range(len(addList_bot) - (len_img-1) ):
    
    
        #img = addList_bot[i]
        
        img = np.array(addList_bot[i:i+len_img])
        img = np.reshape(img, (1,len_img*16))
        
        # if(i<1):
        #     print(img.shape)
        #     print(img)
        
        graphList.append((img,0))

  for i in range(len(addList_clothes)  - len_img-1):
    
        #img = addList_clothes[i]
    
        img = np.array(addList_clothes[i:i+len_img])
        img = np.reshape(img, (1,len_img*16))      
        # if(i<1):
        #     print(img)
        
        graphList.append(((img),1))
        
  for i in range(len(addList_plastics) - len_img-1):
        
        #img = addList_plastics[i]
        img = np.array(addList_plastics[i:i+len_img])
        img = np.reshape(img, (1,len_img*16))    
        # if(i<1):
        #     print(img)
            
        graphList.append(((img),2))
        
  for i in range(len(addList_steel) - len_img-1):
        #img = addList_steel[i]
    
        img = np.array(addList_steel[i:i+len_img])
        img = np.reshape(img, (1,len_img*16))       
        # if(i<1):
        #     print(img)
        graphList.append(((img),3))
  
  
  
  print(len(graphList))
    
    
 
  return graphList




############################## data loading for 3.5 inch#####################

graphList_lablight_3_5 = fileFeedforGNN('lablight_3.5_.txt')
graphList_night_3_5 = fileFeedforGNN('night_3.5_.txt')
graphList_sunny_3_5 = fileFeedforGNN('sunny_3.5_.txt')


lablight_train_len = int(len(graphList_lablight_3_5)*0.7)
night_train_len = int(len(graphList_night_3_5)*0.7)
sunny_tarin_len = int(len(graphList_sunny_3_5)*0.7)


batch_size=64
test_batch_size=64

random.shuffle(graphList_lablight_3_5)
random.shuffle(graphList_night_3_5)
random.shuffle(graphList_sunny_3_5)

train_loader_lablight_3_5 = torch.utils.data.DataLoader(graphList_lablight_3_5[0:lablight_train_len],batch_size)  
test_loader_lablight_3_5 = torch.utils.data.DataLoader(graphList_lablight_3_5[lablight_train_len:],test_batch_size) 

train_loader_night_3_5 = torch.utils.data.DataLoader(graphList_night_3_5[0:night_train_len],batch_size)  
test_loader_night_3_5 = torch.utils.data.DataLoader(graphList_night_3_5[night_train_len:],test_batch_size) 

train_loader_sunny_3_5 = torch.utils.data.DataLoader(graphList_sunny_3_5[0:sunny_tarin_len],batch_size)  
test_loader_sunny_3_5 = torch.utils.data.DataLoader(graphList_sunny_3_5[sunny_tarin_len:],test_batch_size) 

print(len(graphList_lablight_3_5))
print(len(graphList_night_3_5))
print(len(graphList_sunny_3_5))



############################## data loading for 7 inch#####################

graphList_lablight_7= fileFeedforGNN('lablight_7_.txt')
graphList_night_7 = fileFeedforGNN('night_7_.txt')
graphList_sunny_7 = fileFeedforGNN('sunny_7_.txt')


lablight_train_len = int(len(graphList_lablight_7)*0.7)
night_train_len = int(len(graphList_night_7)*0.7)
sunny_tarin_len = int(len(graphList_sunny_7)*0.7)


batch_size=64
test_batch_size=64

random.shuffle(graphList_lablight_7)
random.shuffle(graphList_night_7)
random.shuffle(graphList_sunny_7)

train_loader_lablight_7 = torch.utils.data.DataLoader(graphList_lablight_7[0:lablight_train_len],batch_size)  
test_loader_lablight_7 = torch.utils.data.DataLoader(graphList_lablight_7[lablight_train_len:],test_batch_size) 

train_loader_night_7 = torch.utils.data.DataLoader(graphList_night_7[0:night_train_len],batch_size)  
test_loader_night_7 = torch.utils.data.DataLoader(graphList_night_7[night_train_len:],test_batch_size) 

train_loader_sunny_7= torch.utils.data.DataLoader(graphList_sunny_7[0:sunny_tarin_len],batch_size)  
test_loader_sunny_7= torch.utils.data.DataLoader(graphList_sunny_7[sunny_tarin_len:],test_batch_size) 

print(len(test_loader_sunny_7)*64)

print(len(graphList_lablight_7))
print(len(graphList_night_7))
print(len(graphList_sunny_7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8530a4ea7169> in <module>
#       5 from sklearn.preprocessing import MinMaxScaler
#       6 tform1 = StandardScaler()
# ----> 7 tform=transforms.Compose([
#       8                            transforms.ToTensor()])
#       9 def fileFeedforGNN(name):
#
# NameError: name 'transforms' is not defined

# %%
import torch.utils.data as data
from PIL import Image
import os
import os
import torch.backends.cudnn as cudnn
import torch.utils.data
from torchvision import transforms

from torchvision import datasets

from torch.autograd import Function


class ReverseLayerF(Function):

    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None




import torch.nn as nn

conv_row,conv_col = 1,64
out_channel = 1

class CNNModel(nn.Module):

    def __init__(self):
        super(CNNModel, self).__init__()
        self.feature = nn.Sequential()
        
        self.feature.add_module('f_conv1',nn.Conv1d(1, 2, 20,2))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_conv2',nn.Conv1d(2, 2, 20,2))
        self.feature.add_module('f_relu2', nn.ReLU(True))
        self.feature.add_module('f_conv3',nn.Conv1d(2, 1, 20,2))
        self.feature.add_module('f_relu3', nn.ReLU(True))
        

        
     
       


        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(conv_row * conv_col * out_channel, 32))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_fc2', nn.Linear(32, 16))
        self.class_classifier.add_module('c_relu2', nn.ReLU(True))
        self.class_classifier.add_module('c_fc3', nn.Linear(16, 4))
        self.class_classifier.add_module('c_softmax', nn.Softmax(dim=1))

        self.domain_classifier = nn.Sequential()
        self.domain_classifier.add_module('d_fc1', nn.Linear(conv_row * conv_col * out_channel, 32))
        
        self.domain_classifier.add_module('d_relu1', nn.ReLU(True))
        self.domain_classifier.add_module('d_fc2', nn.Linear(32, 2))
       
        self.domain_classifier.add_module('d_softmax', nn.Softmax(dim=1))

    def forward(self, input_data, alpha):
        #input_data = input_data.expand(input_data.data.shape[0], 3, 28, 28)
        # print("I am in forward")
        # print(input_data.data.shape[0])
        input_data = input_data.float()
        feature = self.feature(input_data)
        feature = feature.view(-1, conv_row * conv_col * out_channel)
        reverse_feature = ReverseLayerF.apply(feature, alpha)
        class_output = self.class_classifier(feature)
        domain_output = self.domain_classifier(reverse_feature)

        return class_output, domain_output

    



def test(dataloader):
    #assert dataset_name in ['MNIST', 'mnist_m']

    model_root = ''
    

    cuda = True
    cudnn.benchmark = True
    batch_size = 64
   
    alpha = 0

    """load data"""




    """ test """

    my_net = torch.load(os.path.join(
        model_root, 'mnist_mnistm_model_epoch_current.pth'
    ))
    my_net = my_net.eval()

    if cuda:
        my_net = my_net.cuda()

    len_dataloader = len(dataloader)
    data_target_iter = iter(dataloader)

    i = 0
    n_total = 0
    n_correct = 0

    while i < len_dataloader:

        # test model using target data
        data_target = next(data_target_iter)
        t_img, t_label = data_target

        batch_size = len(t_label)

        if cuda:
            t_img = t_img.cuda()
            t_label = t_label.cuda()

        class_output, _ = my_net(input_data=t_img, alpha=alpha)
        pred = class_output.data.max(1, keepdim=True)[1]
        n_correct += pred.eq(t_label.data.view_as(pred)).cpu().sum()
        n_total += batch_size

        i += 1

    accu = n_correct.data.numpy() * 1.0 / n_total

    return accu

# %%
import random
import os
import sys
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import numpy as np

from torchvision import datasets
from torchvision import transforms




model_root = 'models'
cuda = True
cudnn.benchmark = True
lr = 1e-3

image_size = 28
n_epoch = 150

manual_seed = random.randint(1, 10000)
random.seed(manual_seed)
torch.manual_seed(manual_seed)

# load data

dataloader_source = train_loader_lablight_7


dataloader_target = train_loader_sunny_7

my_net = CNNModel()

# setup optimizer

class_optimizer = optim.Adam(my_net.class_classifier.parameters(), lr=lr)
discriminator_optimizer =  optim.Adam(my_net.domain_classifier.parameters(), lr=lr)


loss_class = torch.nn.CrossEntropyLoss()
loss_domain = torch.nn.CrossEntropyLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()
    loss_domain = loss_domain.cuda()

for p in my_net.parameters():
    p.requires_grad = True

# training
best_accu_t = 0.0

accList = []
errList = []

for epoch in range(n_epoch):

    len_dataloader_source, len_dataloader_target = len(dataloader_source), len(dataloader_target)
    data_source_iter = iter(dataloader_source)
    data_target_iter = iter(dataloader_target)

    for i in range(len_dataloader_source):

        p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # training model using source data
        data_source = next(data_source_iter)
        s_img, s_label = data_source
        
        # print('\n')
        # print(s_img.shape)
        # print(s_label)

        class_optimizer.zero_grad()
        discriminator_optimizer.zero_grad()
        
        batch_size = len(s_label)

        domain_label = torch.ones(batch_size).long()

        if cuda:
            s_img = s_img.cuda()
            s_label = s_label.cuda()
            domain_label = domain_label.cuda()


        class_output, domain_output = my_net(input_data=s_img, alpha=alpha)
        err_s_label = loss_class(class_output, s_label)
        err_s_domain = loss_domain(domain_output, domain_label)
        
        loss_s_label_domain = err_s_label + err_s_domain
        
        loss_s_label_domain.backward()
        class_optimizer.step()
        discriminator_optimizer.step()
    
    for i in range(len_dataloader_target):

        # training model using target data
        data_target = next(data_target_iter)
        t_img, t_label = data_target
        
        
        # print('\n I am in targert')
        # print(t_img.shape)
        # print(_)

        batch_size = len(t_img)

        domain_label = torch.zeros(batch_size).long()

        if cuda:
            t_img = t_img.cuda()
            t_label = t_label.cuda()
            domain_label = domain_label.cuda()

        _, domain_output = my_net(input_data=t_img, alpha=alpha)
        err_t_domain = loss_domain(domain_output, domain_label)
        err_t_label = loss_class(_,t_label)
        
        err = err_t_domain #+ err_s_domain + err_s_label #+ err_t_label
      
        err.backward()
       
        discriminator_optimizer.step()
        

    sys.stdout.write('\r epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
          % (epoch, i + 1, len_dataloader, err_s_label.data.cpu().numpy(),
             err_s_domain.data.cpu().numpy(), err_t_domain.data.cpu().item()))
    sys.stdout.flush()
    torch.save(my_net, 'mnist_mnistm_model_epoch_current.pth'.format(model_root))

    print('\n')
    accu_s = test(test_loader_lablight_7)
    print('Accuracy of the %s dataset: %f' % ('source===', accu_s))
    accu_t = test(test_loader_sunny_7)
    print('Accuracy of the %s dataset: %f\n' % ('target', accu_t))
    accList.append([accu_s,accu_t])
    if accu_t > best_accu_t:
        best_accu_s = accu_s
        best_accu_t = accu_t
        torch.save(my_net, 'mnist_mnistm_model_epoch_best.pth'.format(model_root))

print('============ Summary ============= \n')
print('Accuracy of the %s dataset: %f' % ('source', best_accu_s))
print('Accuracy of the %s dataset: %f' % ('target', best_accu_t))
print('Corresponding model was save in ' + model_root + 'mnist_mnistm_model_epoch_best.pth')
# Out:
#  epoch: 0, [iter: 38 / all 38], err_s_label: 1.385140, err_s_domain: 0.580347, err_t_domain: 0.638514
#
# Accuracy of the source=== dataset: 0.251962
# Accuracy of the target dataset: 0.280000
#
#  epoch: 1, [iter: 38 / all 38], err_s_label: 1.381264, err_s_domain: 0.786001, err_t_domain: 0.510003
#
# Accuracy of the source=== dataset: 0.251962
# Accuracy of the target dataset: 0.280000
#
#  epoch: 2, [iter: 38 / all 38], err_s_label: 1.376319, err_s_domain: 0.968384, err_t_domain: 0.420415
#
# Accuracy of the source=== dataset: 0.319965
# Accuracy of the target dataset: 0.270244
#
#  epoch: 3, [iter: 38 / all 38], err_s_label: 1.370074, err_s_domain: 1.102146, err_t_domain: 0.374062
#
# Accuracy of the source=== dataset: 0.327812
# Accuracy of the target dataset: 0.249756
#
#  epoch: 4, [iter: 38 / all 38], err_s_label: 1.359944, err_s_domain: 1.177373, err_t_domain: 0.350614
#
# Accuracy of the source=== dataset: 0.364429
# Accuracy of the target dataset: 0.235122
#
#  epoch: 5, [iter: 38 / all 38], err_s_label: 1.345639, err_s_domain: 1.220648, err_t_domain: 0.338290
#
# Accuracy of the source=== dataset: 0.382738
# Accuracy of the target dataset: 0.236098
#
#  epoch: 6, [iter: 38 / all 38], err_s_label: 1.333867, err_s_domain: 1.245764, err_t_domain: 0.331275
#
# Accuracy of the source=== dataset: 0.404534
# Accuracy of the target dataset: 0.230244
#
#  epoch: 7, [iter: 38 / all 38], err_s_label: 1.326805, err_s_domain: 1.261523, err_t_domain: 0.326904
#
# Accuracy of the source=== dataset: 0.407149
# Accuracy of the target dataset: 0.239024
#
#  epoch: 8, [iter: 38 / all 38], err_s_label: 1.322995, err_s_domain: 1.272138, err_t_domain: 0.323981
#
# Accuracy of the source=== dataset: 0.402790
# Accuracy of the target dataset: 0.237073
#
#  epoch: 9, [iter: 38 / all 38], err_s_label: 1.320062, err_s_domain: 1.279685, err_t_domain: 0.321887
#
# Accuracy of the source=== dataset: 0.402790
# Accuracy of the target dataset: 0.239024
#
#  epoch: 10, [iter: 38 / all 38], err_s_label: 1.316295, err_s_domain: 1.285300, err_t_domain: 0.320271
#
# Accuracy of the source=== dataset: 0.403662
# Accuracy of the target dataset: 0.245854
#
#  epoch: 11, [iter: 38 / all 38], err_s_label: 1.312272, err_s_domain: 1.289926, err_t_domain: 0.318839
#
# Accuracy of the source=== dataset: 0.404534
# Accuracy of the target dataset: 0.257561
#
#  epoch: 12, [iter: 38 / all 38], err_s_label: 1.308206, err_s_domain: 1.294489, err_t_domain: 0.317536
#
# Accuracy of the source=== dataset: 0.408021
# Accuracy of the target dataset: 0.262439
#
#  epoch: 13, [iter: 38 / all 38], err_s_label: 1.304400, err_s_domain: 1.298655, err_t_domain: 0.316509
#
# Accuracy of the source=== dataset: 0.408893
# Accuracy of the target dataset: 0.258537
#
#  epoch: 14, [iter: 38 / all 38], err_s_label: 1.301626, err_s_domain: 1.301841, err_t_domain: 0.315775
#
# Accuracy of the source=== dataset: 0.414124
# Accuracy of the target dataset: 0.258537
#
#  epoch: 15, [iter: 38 / all 38], err_s_label: 1.299145, err_s_domain: 1.304139, err_t_domain: 0.315253
#
# Accuracy of the source=== dataset: 0.425458
# Accuracy of the target dataset: 0.247805
#
#  epoch: 16, [iter: 38 / all 38], err_s_label: 1.296947, err_s_domain: 1.305811, err_t_domain: 0.314878
#
# Accuracy of the source=== dataset: 0.428073
# Accuracy of the target dataset: 0.247805
#
#  epoch: 17, [iter: 38 / all 38], err_s_label: 1.295192, err_s_domain: 1.307054, err_t_domain: 0.314599
#
# Accuracy of the source=== dataset: 0.434176
# Accuracy of the target dataset: 0.252683
#
#  epoch: 18, [iter: 38 / all 38], err_s_label: 1.294178, err_s_domain: 1.308008, err_t_domain: 0.314387
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.253659
#
#  epoch: 19, [iter: 38 / all 38], err_s_label: 1.293093, err_s_domain: 1.308753, err_t_domain: 0.314221
#
# Accuracy of the source=== dataset: 0.432432
# Accuracy of the target dataset: 0.254634
#
#  epoch: 20, [iter: 38 / all 38], err_s_label: 1.292424, err_s_domain: 1.309350, err_t_domain: 0.314089
#
# Accuracy of the source=== dataset: 0.430689
# Accuracy of the target dataset: 0.254634
#
#  epoch: 21, [iter: 38 / all 38], err_s_label: 1.291570, err_s_domain: 1.309835, err_t_domain: 0.313982
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.261463
#
#  epoch: 22, [iter: 38 / all 38], err_s_label: 1.291116, err_s_domain: 1.310238, err_t_domain: 0.313894
#
# Accuracy of the source=== dataset: 0.433304
# Accuracy of the target dataset: 0.263415
#
#  epoch: 23, [iter: 38 / all 38], err_s_label: 1.290602, err_s_domain: 1.310573, err_t_domain: 0.313820
#
# Accuracy of the source=== dataset: 0.429817
# Accuracy of the target dataset: 0.263415
#
#  epoch: 24, [iter: 38 / all 38], err_s_label: 1.290022, err_s_domain: 1.310858, err_t_domain: 0.313758
#
# Accuracy of the source=== dataset: 0.427201
# Accuracy of the target dataset: 0.264390
#
#  epoch: 25, [iter: 38 / all 38], err_s_label: 1.289617, err_s_domain: 1.311100, err_t_domain: 0.313706
#
# Accuracy of the source=== dataset: 0.427201
# Accuracy of the target dataset: 0.263415
#
#  epoch: 26, [iter: 38 / all 38], err_s_label: 1.289255, err_s_domain: 1.311309, err_t_domain: 0.313661
#
# Accuracy of the source=== dataset: 0.427201
# Accuracy of the target dataset: 0.262439
#
#  epoch: 27, [iter: 38 / all 38], err_s_label: 1.288618, err_s_domain: 1.311492, err_t_domain: 0.313622
#
# Accuracy of the source=== dataset: 0.427201
# Accuracy of the target dataset: 0.264390
#
#  epoch: 28, [iter: 38 / all 38], err_s_label: 1.288328, err_s_domain: 1.311650, err_t_domain: 0.313588
#
# Accuracy of the source=== dataset: 0.428073
# Accuracy of the target dataset: 0.265366
#
#  epoch: 29, [iter: 38 / all 38], err_s_label: 1.287766, err_s_domain: 1.311791, err_t_domain: 0.313558
#
# Accuracy of the source=== dataset: 0.428073
# Accuracy of the target dataset: 0.267317
#
#  epoch: 30, [iter: 38 / all 38], err_s_label: 1.287507, err_s_domain: 1.311914, err_t_domain: 0.313532
#
# Accuracy of the source=== dataset: 0.428945
# Accuracy of the target dataset: 0.272195
#
#  epoch: 31, [iter: 38 / all 38], err_s_label: 1.286980, err_s_domain: 1.312025, err_t_domain: 0.313509
#
# Accuracy of the source=== dataset: 0.427201
# Accuracy of the target dataset: 0.271220
#
#  epoch: 32, [iter: 38 / all 38], err_s_label: 1.286635, err_s_domain: 1.312122, err_t_domain: 0.313489
#
# Accuracy of the source=== dataset: 0.428945
# Accuracy of the target dataset: 0.274146
#
#  epoch: 33, [iter: 38 / all 38], err_s_label: 1.286142, err_s_domain: 1.312210, err_t_domain: 0.313470
#
# Accuracy of the source=== dataset: 0.428073
# Accuracy of the target dataset: 0.275122
#
#  epoch: 34, [iter: 38 / all 38], err_s_label: 1.286075, err_s_domain: 1.312290, err_t_domain: 0.313454
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.277073
#
#  epoch: 35, [iter: 38 / all 38], err_s_label: 1.285630, err_s_domain: 1.312361, err_t_domain: 0.313439
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.276098
#
#  epoch: 36, [iter: 38 / all 38], err_s_label: 1.285286, err_s_domain: 1.312427, err_t_domain: 0.313426
#
# Accuracy of the source=== dataset: 0.433304
# Accuracy of the target dataset: 0.275122
#
#  epoch: 37, [iter: 38 / all 38], err_s_label: 1.285138, err_s_domain: 1.312485, err_t_domain: 0.313413
#
# Accuracy of the source=== dataset: 0.434176
# Accuracy of the target dataset: 0.274146
#
#  epoch: 38, [iter: 38 / all 38], err_s_label: 1.284761, err_s_domain: 1.312539, err_t_domain: 0.313402
#
# Accuracy of the source=== dataset: 0.434176
# Accuracy of the target dataset: 0.274146
#
#  epoch: 39, [iter: 38 / all 38], err_s_label: 1.284561, err_s_domain: 1.312588, err_t_domain: 0.313392
#
# Accuracy of the source=== dataset: 0.434176
# Accuracy of the target dataset: 0.275122
#
#  epoch: 40, [iter: 38 / all 38], err_s_label: 1.284480, err_s_domain: 1.312633, err_t_domain: 0.313383
#
# Accuracy of the source=== dataset: 0.432432
# Accuracy of the target dataset: 0.277073
#
#  epoch: 41, [iter: 38 / all 38], err_s_label: 1.284178, err_s_domain: 1.312674, err_t_domain: 0.313375
#
# Accuracy of the source=== dataset: 0.430689
# Accuracy of the target dataset: 0.276098
#
#  epoch: 42, [iter: 38 / all 38], err_s_label: 1.284178, err_s_domain: 1.312713, err_t_domain: 0.313367
#
# Accuracy of the source=== dataset: 0.430689
# Accuracy of the target dataset: 0.273171
#
#  epoch: 43, [iter: 38 / all 38], err_s_label: 1.284296, err_s_domain: 1.312747, err_t_domain: 0.313360
#
# Accuracy of the source=== dataset: 0.430689
# Accuracy of the target dataset: 0.273171
#
#  epoch: 44, [iter: 38 / all 38], err_s_label: 1.283828, err_s_domain: 1.312779, err_t_domain: 0.313354
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.274146
#
#  epoch: 45, [iter: 38 / all 38], err_s_label: 1.283783, err_s_domain: 1.312809, err_t_domain: 0.313348
#
# Accuracy of the source=== dataset: 0.432432
# Accuracy of the target dataset: 0.272195
#
#  epoch: 46, [iter: 38 / all 38], err_s_label: 1.283809, err_s_domain: 1.312837, err_t_domain: 0.313342
#
# Accuracy of the source=== dataset: 0.434176
# Accuracy of the target dataset: 0.272195
#
#  epoch: 47, [iter: 38 / all 38], err_s_label: 1.283780, err_s_domain: 1.312863, err_t_domain: 0.313337
#
# Accuracy of the source=== dataset: 0.432432
# Accuracy of the target dataset: 0.276098
#
#  epoch: 48, [iter: 38 / all 38], err_s_label: 1.283849, err_s_domain: 1.312886, err_t_domain: 0.313333
#
# Accuracy of the source=== dataset: 0.432432
# Accuracy of the target dataset: 0.275122
#
#  epoch: 49, [iter: 38 / all 38], err_s_label: 1.283756, err_s_domain: 1.312908, err_t_domain: 0.313328
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.273171
#
#  epoch: 50, [iter: 38 / all 38], err_s_label: 1.283813, err_s_domain: 1.312929, err_t_domain: 0.313324
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.273171
#
#  epoch: 51, [iter: 38 / all 38], err_s_label: 1.283718, err_s_domain: 1.312948, err_t_domain: 0.313320
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.273171
#
#  epoch: 52, [iter: 38 / all 38], err_s_label: 1.283960, err_s_domain: 1.312966, err_t_domain: 0.313317
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.273171
#
#  epoch: 53, [iter: 38 / all 38], err_s_label: 1.283826, err_s_domain: 1.312983, err_t_domain: 0.313314
#
# Accuracy of the source=== dataset: 0.433304
# Accuracy of the target dataset: 0.275122
#
#  epoch: 54, [iter: 38 / all 38], err_s_label: 1.283873, err_s_domain: 1.312998, err_t_domain: 0.313311
#
# Accuracy of the source=== dataset: 0.433304
# Accuracy of the target dataset: 0.273171
#
#  epoch: 55, [iter: 38 / all 38], err_s_label: 1.284044, err_s_domain: 1.313013, err_t_domain: 0.313308
#
# Accuracy of the source=== dataset: 0.432432
# Accuracy of the target dataset: 0.274146
#
#  epoch: 56, [iter: 38 / all 38], err_s_label: 1.284209, err_s_domain: 1.313026, err_t_domain: 0.313305
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.274146
#
#  epoch: 57, [iter: 38 / all 38], err_s_label: 1.284323, err_s_domain: 1.313039, err_t_domain: 0.313303
#
# Accuracy of the source=== dataset: 0.432432
# Accuracy of the target dataset: 0.276098
#
#  epoch: 58, [iter: 38 / all 38], err_s_label: 1.284457, err_s_domain: 1.313052, err_t_domain: 0.313300
#
# Accuracy of the source=== dataset: 0.432432
# Accuracy of the target dataset: 0.276098
#
#  epoch: 59, [iter: 38 / all 38], err_s_label: 1.284553, err_s_domain: 1.313063, err_t_domain: 0.313298
#
# Accuracy of the source=== dataset: 0.429817
# Accuracy of the target dataset: 0.276098
#
#  epoch: 60, [iter: 38 / all 38], err_s_label: 1.284672, err_s_domain: 1.313073, err_t_domain: 0.313296
#
# Accuracy of the source=== dataset: 0.428073
# Accuracy of the target dataset: 0.275122
#
#  epoch: 61, [iter: 38 / all 38], err_s_label: 1.284944, err_s_domain: 1.313083, err_t_domain: 0.313294
#
# Accuracy of the source=== dataset: 0.428073
# Accuracy of the target dataset: 0.277073
#
#  epoch: 62, [iter: 38 / all 38], err_s_label: 1.285164, err_s_domain: 1.313093, err_t_domain: 0.313293
#
# Accuracy of the source=== dataset: 0.428945
# Accuracy of the target dataset: 0.276098
#
#  epoch: 63, [iter: 38 / all 38], err_s_label: 1.285194, err_s_domain: 1.313102, err_t_domain: 0.313291
#
# Accuracy of the source=== dataset: 0.428073
# Accuracy of the target dataset: 0.276098
#
#  epoch: 64, [iter: 38 / all 38], err_s_label: 1.285260, err_s_domain: 1.313110, err_t_domain: 0.313289
#
# Accuracy of the source=== dataset: 0.426330
# Accuracy of the target dataset: 0.278049
#
#  epoch: 65, [iter: 38 / all 38], err_s_label: 1.285805, err_s_domain: 1.313118, err_t_domain: 0.313288
#
# Accuracy of the source=== dataset: 0.423714
# Accuracy of the target dataset: 0.278049
#
#  epoch: 66, [iter: 38 / all 38], err_s_label: 1.285765, err_s_domain: 1.313125, err_t_domain: 0.313287
#
# Accuracy of the source=== dataset: 0.424586
# Accuracy of the target dataset: 0.277073
#
#  epoch: 67, [iter: 38 / all 38], err_s_label: 1.286000, err_s_domain: 1.313132, err_t_domain: 0.313285
#
# Accuracy of the source=== dataset: 0.427201
# Accuracy of the target dataset: 0.279024
#
#  epoch: 68, [iter: 38 / all 38], err_s_label: 1.285929, err_s_domain: 1.313139, err_t_domain: 0.313284
#
# Accuracy of the source=== dataset: 0.427201
# Accuracy of the target dataset: 0.278049
#
#  epoch: 69, [iter: 38 / all 38], err_s_label: 1.286159, err_s_domain: 1.313145, err_t_domain: 0.313283
#
# Accuracy of the source=== dataset: 0.430689
# Accuracy of the target dataset: 0.276098
#
#  epoch: 70, [iter: 38 / all 38], err_s_label: 1.286196, err_s_domain: 1.313151, err_t_domain: 0.313282
#
# Accuracy of the source=== dataset: 0.431561
# Accuracy of the target dataset: 0.275122
#
#  epoch: 71, [iter: 38 / all 38], err_s_label: 1.286476, err_s_domain: 1.313157, err_t_domain: 0.313281
#
# Accuracy of the source=== dataset: 0.433304
# Accuracy of the target dataset: 0.275122
#
#  epoch: 72, [iter: 38 / all 38], err_s_label: 1.286342, err_s_domain: 1.313162, err_t_domain: 0.313280
#
# Accuracy of the source=== dataset: 0.434176
# Accuracy of the target dataset: 0.275122
#
#  epoch: 73, [iter: 38 / all 38], err_s_label: 1.286731, err_s_domain: 1.313167, err_t_domain: 0.313279
#
# Accuracy of the source=== dataset: 0.436792
# Accuracy of the target dataset: 0.276098
#
#  epoch: 74, [iter: 38 / all 38], err_s_label: 1.286813, err_s_domain: 1.313172, err_t_domain: 0.313278
#
# Accuracy of the source=== dataset: 0.439407
# Accuracy of the target dataset: 0.275122
#
#  epoch: 75, [iter: 38 / all 38], err_s_label: 1.287048, err_s_domain: 1.313176, err_t_domain: 0.313277
#
# Accuracy of the source=== dataset: 0.441151
# Accuracy of the target dataset: 0.275122
#
#  epoch: 76, [iter: 38 / all 38], err_s_label: 1.286991, err_s_domain: 1.313180, err_t_domain: 0.313276
#
# Accuracy of the source=== dataset: 0.442023
# Accuracy of the target dataset: 0.273171
#
#  epoch: 77, [iter: 38 / all 38], err_s_label: 1.287168, err_s_domain: 1.313184, err_t_domain: 0.313276
#
# Accuracy of the source=== dataset: 0.441151
# Accuracy of the target dataset: 0.274146
#
#  epoch: 78, [iter: 38 / all 38], err_s_label: 1.287300, err_s_domain: 1.313188, err_t_domain: 0.313275
#
# Accuracy of the source=== dataset: 0.443766
# Accuracy of the target dataset: 0.275122
#
#  epoch: 79, [iter: 38 / all 38], err_s_label: 1.287252, err_s_domain: 1.313191, err_t_domain: 0.313274
#
# Accuracy of the source=== dataset: 0.446382
# Accuracy of the target dataset: 0.276098
#
#  epoch: 80, [iter: 38 / all 38], err_s_label: 1.287431, err_s_domain: 1.313195, err_t_domain: 0.313274
#
# Accuracy of the source=== dataset: 0.444638
# Accuracy of the target dataset: 0.276098
#
#  epoch: 81, [iter: 38 / all 38], err_s_label: 1.287353, err_s_domain: 1.313198, err_t_domain: 0.313273
#
# Accuracy of the source=== dataset: 0.444638
# Accuracy of the target dataset: 0.275122
#
#  epoch: 82, [iter: 38 / all 38], err_s_label: 1.287179, err_s_domain: 1.313201, err_t_domain: 0.313272
#
# Accuracy of the source=== dataset: 0.445510
# Accuracy of the target dataset: 0.277073
#
#  epoch: 83, [iter: 38 / all 38], err_s_label: 1.287330, err_s_domain: 1.313204, err_t_domain: 0.313272
#
# Accuracy of the source=== dataset: 0.443766
# Accuracy of the target dataset: 0.278049
#
#  epoch: 84, [iter: 38 / all 38], err_s_label: 1.287526, err_s_domain: 1.313207, err_t_domain: 0.313271
#
# Accuracy of the source=== dataset: 0.440279
# Accuracy of the target dataset: 0.278049
#
#  epoch: 85, [iter: 38 / all 38], err_s_label: 1.287261, err_s_domain: 1.313210, err_t_domain: 0.313271
#
# Accuracy of the source=== dataset: 0.441151
# Accuracy of the target dataset: 0.278049
#
#  epoch: 86, [iter: 38 / all 38], err_s_label: 1.287405, err_s_domain: 1.313212, err_t_domain: 0.313270
#
# Accuracy of the source=== dataset: 0.439407
# Accuracy of the target dataset: 0.279024
#
#  epoch: 87, [iter: 38 / all 38], err_s_label: 1.287285, err_s_domain: 1.313215, err_t_domain: 0.313270
#
# Accuracy of the source=== dataset: 0.440279
# Accuracy of the target dataset: 0.279024
#
#  epoch: 88, [iter: 38 / all 38], err_s_label: 1.287342, err_s_domain: 1.313217, err_t_domain: 0.313270
#
# Accuracy of the source=== dataset: 0.441151
# Accuracy of the target dataset: 0.280976
#
#  epoch: 89, [iter: 38 / all 38], err_s_label: 1.287081, err_s_domain: 1.313219, err_t_domain: 0.313269
#
# Accuracy of the source=== dataset: 0.443766
# Accuracy of the target dataset: 0.280000
#
#  epoch: 90, [iter: 38 / all 38], err_s_label: 1.287180, err_s_domain: 1.313221, err_t_domain: 0.313269
#
# Accuracy of the source=== dataset: 0.443766
# Accuracy of the target dataset: 0.281951
#
#  epoch: 91, [iter: 38 / all 38], err_s_label: 1.286899, err_s_domain: 1.313223, err_t_domain: 0.313269
#
# Accuracy of the source=== dataset: 0.442895
# Accuracy of the target dataset: 0.283902
#
#  epoch: 92, [iter: 38 / all 38], err_s_label: 1.286826, err_s_domain: 1.313225, err_t_domain: 0.313268
#
# Accuracy of the source=== dataset: 0.442023
# Accuracy of the target dataset: 0.283902
#
#  epoch: 93, [iter: 38 / all 38], err_s_label: 1.286898, err_s_domain: 1.313226, err_t_domain: 0.313268
#
# Accuracy of the source=== dataset: 0.440279
# Accuracy of the target dataset: 0.281951
#
#  epoch: 94, [iter: 38 / all 38], err_s_label: 1.286659, err_s_domain: 1.313228, err_t_domain: 0.313268
#
# Accuracy of the source=== dataset: 0.437663
# Accuracy of the target dataset: 0.281951
#
#  epoch: 95, [iter: 38 / all 38], err_s_label: 1.286549, err_s_domain: 1.313230, err_t_domain: 0.313267
#
# Accuracy of the source=== dataset: 0.438535
# Accuracy of the target dataset: 0.281951
#
#  epoch: 96, [iter: 38 / all 38], err_s_label: 1.286441, err_s_domain: 1.313231, err_t_domain: 0.313267
#
# Accuracy of the source=== dataset: 0.438535
# Accuracy of the target dataset: 0.282927
#
#  epoch: 97, [iter: 38 / all 38], err_s_label: 1.286240, err_s_domain: 1.313233, err_t_domain: 0.313267
#
# Accuracy of the source=== dataset: 0.439407
# Accuracy of the target dataset: 0.282927
#
#  epoch: 98, [iter: 38 / all 38], err_s_label: 1.286071, err_s_domain: 1.313234, err_t_domain: 0.313267
#
# Accuracy of the source=== dataset: 0.441151
# Accuracy of the target dataset: 0.283902
#
#  epoch: 99, [iter: 38 / all 38], err_s_label: 1.286220, err_s_domain: 1.313235, err_t_domain: 0.313266
#
# Accuracy of the source=== dataset: 0.441151
# Accuracy of the target dataset: 0.283902
#
#  epoch: 100, [iter: 38 / all 38], err_s_label: 1.285787, err_s_domain: 1.313236, err_t_domain: 0.313266
#
# Accuracy of the source=== dataset: 0.442023
# Accuracy of the target dataset: 0.285854
#
#  epoch: 101, [iter: 38 / all 38], err_s_label: 1.285812, err_s_domain: 1.313238, err_t_domain: 0.313266
#
# Accuracy of the source=== dataset: 0.440279
# Accuracy of the target dataset: 0.283902
#
#  epoch: 102, [iter: 38 / all 38], err_s_label: 1.285413, err_s_domain: 1.313239, err_t_domain: 0.313266
#
# Accuracy of the source=== dataset: 0.440279
# Accuracy of the target dataset: 0.283902
#
#  epoch: 103, [iter: 38 / all 38], err_s_label: 1.285397, err_s_domain: 1.313240, err_t_domain: 0.313266
#
# Accuracy of the source=== dataset: 0.439407
# Accuracy of the target dataset: 0.282927
#
#  epoch: 104, [iter: 38 / all 38], err_s_label: 1.284949, err_s_domain: 1.313241, err_t_domain: 0.313265
#
# Accuracy of the source=== dataset: 0.442023
# Accuracy of the target dataset: 0.283902
#
#  epoch: 105, [iter: 38 / all 38], err_s_label: 1.284959, err_s_domain: 1.313242, err_t_domain: 0.313265
#
# Accuracy of the source=== dataset: 0.439407
# Accuracy of the target dataset: 0.285854
#
#  epoch: 106, [iter: 38 / all 38], err_s_label: 1.284650, err_s_domain: 1.313243, err_t_domain: 0.313265
#
# Accuracy of the source=== dataset: 0.439407
# Accuracy of the target dataset: 0.286829
#
#  epoch: 107, [iter: 38 / all 38], err_s_label: 1.284319, err_s_domain: 1.313244, err_t_domain: 0.313265
#
# Accuracy of the source=== dataset: 0.437663
# Accuracy of the target dataset: 0.288780
#
#  epoch: 108, [iter: 38 / all 38], err_s_label: 1.284291, err_s_domain: 1.313245, err_t_domain: 0.313265
#
# Accuracy of the source=== dataset: 0.438535
# Accuracy of the target dataset: 0.289756
#
#  epoch: 109, [iter: 38 / all 38], err_s_label: 1.283888, err_s_domain: 1.313246, err_t_domain: 0.313265
#
# Accuracy of the source=== dataset: 0.441151
# Accuracy of the target dataset: 0.291707
#
#  epoch: 110, [iter: 38 / all 38], err_s_label: 1.283716, err_s_domain: 1.313246, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.440279
# Accuracy of the target dataset: 0.291707
#
#  epoch: 111, [iter: 38 / all 38], err_s_label: 1.283672, err_s_domain: 1.313247, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.442023
# Accuracy of the target dataset: 0.291707
#
#  epoch: 112, [iter: 38 / all 38], err_s_label: 1.283255, err_s_domain: 1.313247, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.439407
# Accuracy of the target dataset: 0.292683
#
#  epoch: 113, [iter: 38 / all 38], err_s_label: 1.282823, err_s_domain: 1.313248, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.440279
# Accuracy of the target dataset: 0.293659
#
#  epoch: 114, [iter: 38 / all 38], err_s_label: 1.282687, err_s_domain: 1.313249, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.441151
# Accuracy of the target dataset: 0.292683
#
#  epoch: 115, [iter: 38 / all 38], err_s_label: 1.282649, err_s_domain: 1.313249, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.444638
# Accuracy of the target dataset: 0.293659
#
#  epoch: 116, [iter: 38 / all 38], err_s_label: 1.282341, err_s_domain: 1.313250, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.445510
# Accuracy of the target dataset: 0.293659
#
#  epoch: 117, [iter: 38 / all 38], err_s_label: 1.282275, err_s_domain: 1.313251, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.448126
# Accuracy of the target dataset: 0.292683
#
#  epoch: 118, [iter: 38 / all 38], err_s_label: 1.282097, err_s_domain: 1.313251, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.450741
# Accuracy of the target dataset: 0.293659
#
#  epoch: 119, [iter: 38 / all 38], err_s_label: 1.281908, err_s_domain: 1.313251, err_t_domain: 0.313264
#
# Accuracy of the source=== dataset: 0.452485
# Accuracy of the target dataset: 0.295610
#
#  epoch: 120, [iter: 38 / all 38], err_s_label: 1.281703, err_s_domain: 1.313252, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.452485
# Accuracy of the target dataset: 0.291707
#
#  epoch: 121, [iter: 38 / all 38], err_s_label: 1.281365, err_s_domain: 1.313252, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.453357
# Accuracy of the target dataset: 0.291707
#
#  epoch: 122, [iter: 38 / all 38], err_s_label: 1.280990, err_s_domain: 1.313253, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.452485
# Accuracy of the target dataset: 0.290732
#
#  epoch: 123, [iter: 38 / all 38], err_s_label: 1.280654, err_s_domain: 1.313253, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.452485
# Accuracy of the target dataset: 0.292683
#
#  epoch: 124, [iter: 38 / all 38], err_s_label: 1.280401, err_s_domain: 1.313254, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.453357
# Accuracy of the target dataset: 0.287805
#
#  epoch: 125, [iter: 38 / all 38], err_s_label: 1.279874, err_s_domain: 1.313254, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.455972
# Accuracy of the target dataset: 0.291707
#
#  epoch: 126, [iter: 38 / all 38], err_s_label: 1.279623, err_s_domain: 1.313254, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.459459
# Accuracy of the target dataset: 0.289756
#
#  epoch: 127, [iter: 38 / all 38], err_s_label: 1.279046, err_s_domain: 1.313255, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.459459
# Accuracy of the target dataset: 0.290732
#
#  epoch: 128, [iter: 38 / all 38], err_s_label: 1.278601, err_s_domain: 1.313255, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.462075
# Accuracy of the target dataset: 0.287805
#
#  epoch: 129, [iter: 38 / all 38], err_s_label: 1.278202, err_s_domain: 1.313255, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.461203
# Accuracy of the target dataset: 0.286829
#
#  epoch: 130, [iter: 38 / all 38], err_s_label: 1.277744, err_s_domain: 1.313256, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.462947
# Accuracy of the target dataset: 0.285854
#
#  epoch: 131, [iter: 38 / all 38], err_s_label: 1.277419, err_s_domain: 1.313256, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.462947
# Accuracy of the target dataset: 0.283902
#
#  epoch: 132, [iter: 38 / all 38], err_s_label: 1.276782, err_s_domain: 1.313256, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.462947
# Accuracy of the target dataset: 0.281951
#
#  epoch: 133, [iter: 38 / all 38], err_s_label: 1.276303, err_s_domain: 1.313256, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.462947
# Accuracy of the target dataset: 0.281951
#
#  epoch: 134, [iter: 38 / all 38], err_s_label: 1.275697, err_s_domain: 1.313257, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.462947
# Accuracy of the target dataset: 0.281951
#
#  epoch: 135, [iter: 38 / all 38], err_s_label: 1.275030, err_s_domain: 1.313257, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.465562
# Accuracy of the target dataset: 0.279024
#
#  epoch: 136, [iter: 38 / all 38], err_s_label: 1.274402, err_s_domain: 1.313257, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.465562
# Accuracy of the target dataset: 0.278049
#
#  epoch: 137, [iter: 38 / all 38], err_s_label: 1.273625, err_s_domain: 1.313257, err_t_domain: 0.313263
#
# Accuracy of the source=== dataset: 0.464690
# Accuracy of the target dataset: 0.276098
#
#  epoch: 138, [iter: 38 / all 38], err_s_label: 1.272983, err_s_domain: 1.313258, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.465562
# Accuracy of the target dataset: 0.276098
#
#  epoch: 139, [iter: 38 / all 38], err_s_label: 1.272302, err_s_domain: 1.313258, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.464690
# Accuracy of the target dataset: 0.276098
#
#  epoch: 140, [iter: 38 / all 38], err_s_label: 1.271713, err_s_domain: 1.313258, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.463819
# Accuracy of the target dataset: 0.273171
#
#  epoch: 141, [iter: 38 / all 38], err_s_label: 1.271094, err_s_domain: 1.313258, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.465562
# Accuracy of the target dataset: 0.274146
#
#  epoch: 142, [iter: 38 / all 38], err_s_label: 1.270622, err_s_domain: 1.313258, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.466434
# Accuracy of the target dataset: 0.274146
#
#  epoch: 143, [iter: 38 / all 38], err_s_label: 1.270099, err_s_domain: 1.313259, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.468178
# Accuracy of the target dataset: 0.272195
#
#  epoch: 144, [iter: 38 / all 38], err_s_label: 1.269420, err_s_domain: 1.313259, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.467306
# Accuracy of the target dataset: 0.272195
#
#  epoch: 145, [iter: 38 / all 38], err_s_label: 1.269033, err_s_domain: 1.313259, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.467306
# Accuracy of the target dataset: 0.272195
#
#  epoch: 146, [iter: 38 / all 38], err_s_label: 1.268657, err_s_domain: 1.313259, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.467306
# Accuracy of the target dataset: 0.269268
#
#  epoch: 147, [iter: 38 / all 38], err_s_label: 1.267980, err_s_domain: 1.313259, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.466434
# Accuracy of the target dataset: 0.268293
#
#  epoch: 148, [iter: 38 / all 38], err_s_label: 1.267455, err_s_domain: 1.313259, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.466434
# Accuracy of the target dataset: 0.268293
#
#  epoch: 149, [iter: 38 / all 38], err_s_label: 1.266958, err_s_domain: 1.313259, err_t_domain: 0.313262
#
# Accuracy of the source=== dataset: 0.466434
# Accuracy of the target dataset: 0.268293
#
# ============ Summary =============
#
# Accuracy of the source dataset: 0.452485
# Accuracy of the target dataset: 0.295610
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
