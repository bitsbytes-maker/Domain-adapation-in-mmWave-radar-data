# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from scipy.spatial.distance import cdist

import random
import os
import sys
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import numpy as np

from torchvision import datasets
from torchvision import transforms

# %%
import pandas as pd
import numpy as np
import random
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
tform1 = StandardScaler()
tform=transforms.Compose([
                           transforms.ToTensor()])
def fileFeedforGNN(name):

  data = pd.read_table(name)

  

  y = data.iloc[:,-3].values
  
  
  print(np.unique(y))


  graphList = []
  


    
  #num_objects	r_std	r_var	r_mean	r_min	r_max	snr_std	snr_var	snr_mean	snr_min	snr_max	noise_std	noise_var	noise_mean	noise_min	noise_max	obj	environment	
  X_array = data.iloc[:, 0:16].values

  X_array = tform1.fit_transform(X_array)
  

  addList_bot, addList_clothes, addList_plastics, addList_steel  = [],[],[],[]
    
  for i in range(len(X_array)):
    intarray = X_array[i]
    if(y[i] =='bot'):
      addList_bot.append(intarray)
    elif (y[i] == 'clothes'):
      addList_clothes.append(intarray)
    elif (y[i] == 'plastic'):
      addList_plastics.append(intarray)
    elif (y[i] == 'steel'):
      addList_steel.append(intarray)
  
  len_img = 1
  for i in range(len(addList_bot) - (len_img-1) ):
    
    
        img = addList_bot[i]
        
        # img = np.array(addList_bot[i:i+len_img])
        # img = np.reshape(img, (1,len_img*16))
        
        # if(i<1):
        #     print(img.shape)
        #     print(img)
        
        graphList.append((img,0))

  for i in range(len(addList_clothes)  - len_img-1):
    
        img = addList_clothes[i]
    
        # img = np.array(addList_clothes[i:i+len_img])
        # img = np.reshape(img, (1,len_img*16))      
        # if(i<1):
        #     print(img)
        
        graphList.append(((img),1))
        
  for i in range(len(addList_plastics) - len_img-1):
        
        img = addList_plastics[i]
        # img = np.array(addList_plastics[i:i+len_img])
        # img = np.reshape(img, (1,len_img*16))    
        # if(i<1):
        #     print(img)
            
        graphList.append(((img),2))
        
  for i in range(len(addList_steel) - len_img-1):
        img = addList_steel[i]
    
        # img = np.array(addList_steel[i:i+len_img])
        # img = np.reshape(img, (1,len_img*16))       
        # if(i<1):
        #     print(img)
        graphList.append(((img),3))
  
  
  
  print(len(graphList))
    
    
 
  return graphList




############################## data loading for 3.5 inch#####################

graphList_lablight_3_5 = fileFeedforGNN('lablight_3.5_.txt')
graphList_night_3_5 = fileFeedforGNN('night_3.5_.txt')
graphList_sunny_3_5 = fileFeedforGNN('sunny_3.5_.txt')


lablight_train_len = int(len(graphList_lablight_3_5)*0.7)
night_train_len = int(len(graphList_night_3_5)*0.7)
sunny_tarin_len = int(len(graphList_sunny_3_5)*0.7)


batch_size=64
test_batch_size=64

random.shuffle(graphList_lablight_3_5)
random.shuffle(graphList_night_3_5)
random.shuffle(graphList_sunny_3_5)

train_loader_lablight_3_5 = torch.utils.data.DataLoader(graphList_lablight_3_5[0:lablight_train_len],batch_size)  
test_loader_lablight_3_5 = torch.utils.data.DataLoader(graphList_lablight_3_5[lablight_train_len:],test_batch_size) 

train_loader_night_3_5 = torch.utils.data.DataLoader(graphList_night_3_5[0:night_train_len],batch_size)  
test_loader_night_3_5 = torch.utils.data.DataLoader(graphList_night_3_5[night_train_len:],test_batch_size) 

train_loader_sunny_3_5 = torch.utils.data.DataLoader(graphList_sunny_3_5[0:sunny_tarin_len],batch_size)  
test_loader_sunny_3_5 = torch.utils.data.DataLoader(graphList_sunny_3_5[sunny_tarin_len:],test_batch_size) 

print(len(graphList_lablight_3_5))
print(len(graphList_night_3_5))
print(len(graphList_sunny_3_5))



############################## data loading for 7 inch#####################

graphList_lablight_7= fileFeedforGNN('lablight_7_.txt')
graphList_night_7 = fileFeedforGNN('night_7_.txt')
graphList_sunny_7 = fileFeedforGNN('sunny_7_.txt')


lablight_train_len = int(len(graphList_lablight_7)*0.7)
night_train_len = int(len(graphList_night_7)*0.7)
sunny_tarin_len = int(len(graphList_sunny_7)*0.7)


batch_size=64
test_batch_size=64

random.shuffle(graphList_lablight_7)
random.shuffle(graphList_night_7)
random.shuffle(graphList_sunny_7)

train_loader_lablight_7 = torch.utils.data.DataLoader(graphList_lablight_7[0:lablight_train_len],batch_size)  
test_loader_lablight_7 = torch.utils.data.DataLoader(graphList_lablight_7[lablight_train_len:],test_batch_size) 

train_loader_night_7 = torch.utils.data.DataLoader(graphList_night_7[0:night_train_len],batch_size)  
test_loader_night_7 = torch.utils.data.DataLoader(graphList_night_7[night_train_len:],test_batch_size) 

train_loader_sunny_7= torch.utils.data.DataLoader(graphList_sunny_7[0:sunny_tarin_len],batch_size)  
test_loader_sunny_7= torch.utils.data.DataLoader(graphList_sunny_7[sunny_tarin_len:],test_batch_size) 

print(len(test_loader_sunny_7)*64)

print(len(graphList_lablight_7))
print(len(graphList_night_7))
print(len(graphList_sunny_7))
# Out:
# ['bot' 'clothes' 'plastic' 'steel']
# 4210
# ['bot' 'clothes' 'plastic' 'steel']
# 3701
# ['bot' 'clothes' 'plastic' 'steel']
# 3688
# 4210
# 3701
# 3688
# ['bot' 'clothes' 'plastic' 'steel']
# 3978
# ['bot' 'clothes' 'plastic' 'steel']
# 3929
# ['bot' 'clothes' 'plastic' 'steel']
# 3571
# 1088
# 3978
# 3929
# 3571

# %%
import torch.utils.data as data
from PIL import Image
import os
import os
import torch.backends.cudnn as cudnn
import torch.utils.data
from torchvision import transforms

from torchvision import datasets

from torch.autograd import Function


class ReverseLayerF(Function):

    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None




import torch.nn as nn

conv_row,conv_col = 1,64
out_channel = 1

class CNNModel(nn.Module):

    def __init__(self):
        super(CNNModel, self).__init__()
        self.feature = nn.Sequential()
        
        self.feature.add_module('f_fc1',nn.Linear(16,16))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_fc2',nn.Linear(16, 16))
        self.feature.add_module('f_relu2', nn.ReLU(True))
        
        

        
     
       


        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(16, 4))
        
        self.class_classifier.add_module('c_softmax', nn.Softmax(dim=1))

        self.domain_classifier = nn.Sequential()
        self.domain_classifier.add_module('d_fc1', nn.Linear(16, 2))
       
        self.domain_classifier.add_module('d_softmax', nn.Softmax(dim=1))

    def forward(self, input_data, alpha):
        #input_data = input_data.expand(input_data.data.shape[0], 3, 28, 28)
        # print("I am in forward")
        # print(input_data.data.shape[0])
        input_data = input_data.float()
        feature = self.feature(input_data)
        feature = feature.view(-1, 16)
        reverse_feature = ReverseLayerF.apply(feature, alpha)
        class_output = self.class_classifier(feature)
        domain_output = self.domain_classifier(reverse_feature)

        return class_output, domain_output

    



def test(dataloader):
    #assert dataset_name in ['MNIST', 'mnist_m']

    model_root = ''
    

    cuda = True
    cudnn.benchmark = True
    batch_size = 64
   
    alpha = 0

    """load data"""




    """ test """

    my_net = torch.load(os.path.join(
        model_root, 'mnist_mnistm_model_epoch_current.pth'
    ))
    my_net = my_net.eval()

    if cuda:
        my_net = my_net.cuda()

    len_dataloader = len(dataloader)
    data_target_iter = iter(dataloader)

    i = 0
    n_total = 0
    n_correct = 0

    while i < len_dataloader:

        # test model using target data
        data_target = next(data_target_iter)
        t_img, t_label = data_target

        batch_size = len(t_label)

        if cuda:
            t_img = t_img.cuda()
            t_label = t_label.cuda()

        class_output, _ = my_net(input_data=t_img, alpha=alpha)
        pred = class_output.data.max(1, keepdim=True)[1]
        n_correct += pred.eq(t_label.data.view_as(pred)).cpu().sum()
        n_total += batch_size

        i += 1

    accu = n_correct.data.numpy() * 1.0 / n_total

    return accu

# %%
import random
import os
import sys
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import numpy as np

from torchvision import datasets
from torchvision import transforms




model_root = 'models'
cuda = True
cudnn.benchmark = True
lr = 1e-3

image_size = 28
n_epoch = 150

manual_seed = random.randint(1, 10000)
random.seed(manual_seed)
torch.manual_seed(manual_seed)

# load data

dataloader_source = train_loader_lablight_7


dataloader_target = train_loader_sunny_7

my_net = CNNModel()

# setup optimizer

optimizer = optim.Adam(my_net.parameters(), lr=lr)

loss_class = torch.nn.CrossEntropyLoss()
loss_domain = torch.nn.CrossEntropyLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()
    loss_domain = loss_domain.cuda()

for p in my_net.parameters():
    p.requires_grad = True

# training
best_accu_t = 0.0

accList = []
errList = []

for epoch in range(n_epoch):

    len_dataloader = min(len(dataloader_source), len(dataloader_target))
    data_source_iter = iter(dataloader_source)
    data_target_iter = iter(dataloader_target)

    for i in range(len_dataloader):

        p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
        alpha = 2. / (1. + np.exp(-10 * p)) - 1

        # training model using source data
        data_source = next(data_source_iter)
        s_img, s_label = data_source
        
        # print('\n')
        # print(s_img.shape)
        # print(s_label)

        my_net.zero_grad()
        batch_size = len(s_label)

        domain_label = torch.ones(batch_size).long()

        if cuda:
            s_img = s_img.cuda()
            s_label = s_label.cuda()
            domain_label = domain_label.cuda()


        class_output, domain_output = my_net(input_data=s_img, alpha=alpha)
        err_s_label = loss_class(class_output, s_label)
        err_s_domain = loss_domain(domain_output, domain_label)

        # training model using target data
        data_target = next(data_target_iter)
        t_img, t_label = data_target
        
        
        # print('\n I am in targert')
        # print(t_img.shape)
        # print(_)

        batch_size = len(t_img)

        domain_label = torch.zeros(batch_size).long()

        if cuda:
            t_img = t_img.cuda()
            t_label = t_label.cuda()
            domain_label = domain_label.cuda()

        _, domain_output = my_net(input_data=t_img, alpha=alpha)
        err_t_domain = loss_domain(domain_output, domain_label)
        err_t_label = loss_class(_,t_label)
        
        err = err_t_domain + err_s_domain + err_s_label #+ err_t_label
      
        err.backward()
       
        
        optimizer.step()
        optimizer.zero_grad()
        errList.append(err)

        sys.stdout.write('\r epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
              % (epoch, i + 1, len_dataloader, err_s_label.data.cpu().numpy(),
                 err_s_domain.data.cpu().numpy(), err_t_domain.data.cpu().item()))
        sys.stdout.flush()
        torch.save(my_net, 'mnist_mnistm_model_epoch_current.pth'.format(model_root))

    print('\n')
    accu_s = test(test_loader_lablight_7)
    print('Accuracy of the %s dataset: %f' % ('source===', accu_s))
    accu_t = test(test_loader_sunny_7)
    print('Accuracy of the %s dataset: %f\n' % ('target', accu_t))
    accList.append([accu_s,accu_t])
    if accu_t > best_accu_t:
        best_accu_s = accu_s
        best_accu_t = accu_t
        torch.save(my_net, 'mnist_mnistm_model_epoch_best.pth'.format(model_root))

print('============ Summary ============= \n')
print('Accuracy of the %s dataset: %f' % ('source', best_accu_s))
print('Accuracy of the %s dataset: %f' % ('target', best_accu_t))
print('Corresponding model was save in ' + model_root + 'mnist_mnistm_model_epoch_best.pth')
# Out:
#  epoch: 0, [iter: 40 / all 40], err_s_label: 1.356913, err_s_domain: 0.700624, err_t_domain: 0.704717
#
# Accuracy of the source=== dataset: 0.309045
# Accuracy of the target dataset: 0.267724
#
#  epoch: 1, [iter: 40 / all 40], err_s_label: 1.310879, err_s_domain: 0.703133, err_t_domain: 0.702092
#
# Accuracy of the source=== dataset: 0.407873
# Accuracy of the target dataset: 0.280784
#
#  epoch: 2, [iter: 40 / all 40], err_s_label: 1.262295, err_s_domain: 0.689505, err_t_domain: 0.718924
#
# Accuracy of the source=== dataset: 0.458961
# Accuracy of the target dataset: 0.367537
#
#  epoch: 3, [iter: 40 / all 40], err_s_label: 1.224385, err_s_domain: 0.685233, err_t_domain: 0.727317
#
# Accuracy of the source=== dataset: 0.482412
# Accuracy of the target dataset: 0.370336
#
#  epoch: 4, [iter: 40 / all 40], err_s_label: 1.198504, err_s_domain: 0.683535, err_t_domain: 0.718889
#
# Accuracy of the source=== dataset: 0.501675
# Accuracy of the target dataset: 0.370336
#
#  epoch: 5, [iter: 40 / all 40], err_s_label: 1.180577, err_s_domain: 0.684665, err_t_domain: 0.701270
#
# Accuracy of the source=== dataset: 0.541876
# Accuracy of the target dataset: 0.362873
#
#  epoch: 6, [iter: 40 / all 40], err_s_label: 1.166371, err_s_domain: 0.688560, err_t_domain: 0.685560
#
# Accuracy of the source=== dataset: 0.565327
# Accuracy of the target dataset: 0.360075
#
#  epoch: 7, [iter: 40 / all 40], err_s_label: 1.155705, err_s_domain: 0.694534, err_t_domain: 0.674692
#
# Accuracy of the source=== dataset: 0.571189
# Accuracy of the target dataset: 0.361940
#
#  epoch: 8, [iter: 40 / all 40], err_s_label: 1.147242, err_s_domain: 0.699944, err_t_domain: 0.668954
#
# Accuracy of the source=== dataset: 0.576214
# Accuracy of the target dataset: 0.361007
#
#  epoch: 9, [iter: 40 / all 40], err_s_label: 1.140290, err_s_domain: 0.704899, err_t_domain: 0.665638
#
# Accuracy of the source=== dataset: 0.583752
# Accuracy of the target dataset: 0.368470
#
#  epoch: 10, [iter: 40 / all 40], err_s_label: 1.134675, err_s_domain: 0.708094, err_t_domain: 0.663362
#
# Accuracy of the source=== dataset: 0.600503
# Accuracy of the target dataset: 0.363806
#
#  epoch: 11, [iter: 40 / all 40], err_s_label: 1.130962, err_s_domain: 0.709312, err_t_domain: 0.660529
#
# Accuracy of the source=== dataset: 0.608878
# Accuracy of the target dataset: 0.366604
#
#  epoch: 12, [iter: 40 / all 40], err_s_label: 1.128076, err_s_domain: 0.709037, err_t_domain: 0.657900
#
# Accuracy of the source=== dataset: 0.617253
# Accuracy of the target dataset: 0.367537
#
#  epoch: 13, [iter: 40 / all 40], err_s_label: 1.125208, err_s_domain: 0.708254, err_t_domain: 0.656806
#
# Accuracy of the source=== dataset: 0.625628
# Accuracy of the target dataset: 0.358209
#
#  epoch: 14, [iter: 40 / all 40], err_s_label: 1.121526, err_s_domain: 0.706947, err_t_domain: 0.658273
#
# Accuracy of the source=== dataset: 0.632328
# Accuracy of the target dataset: 0.355410
#
#  epoch: 15, [iter: 40 / all 40], err_s_label: 1.117435, err_s_domain: 0.706404, err_t_domain: 0.662064
#
# Accuracy of the source=== dataset: 0.639028
# Accuracy of the target dataset: 0.356343
#
#  epoch: 16, [iter: 40 / all 40], err_s_label: 1.113145, err_s_domain: 0.707437, err_t_domain: 0.666743
#
# Accuracy of the source=== dataset: 0.646566
# Accuracy of the target dataset: 0.356343
#
#  epoch: 17, [iter: 40 / all 40], err_s_label: 1.108992, err_s_domain: 0.708433, err_t_domain: 0.671058
#
# Accuracy of the source=== dataset: 0.650754
# Accuracy of the target dataset: 0.351679
#
#  epoch: 18, [iter: 40 / all 40], err_s_label: 1.104782, err_s_domain: 0.707946, err_t_domain: 0.672387
#
# Accuracy of the source=== dataset: 0.652429
# Accuracy of the target dataset: 0.349813
#
#  epoch: 19, [iter: 40 / all 40], err_s_label: 1.100227, err_s_domain: 0.706467, err_t_domain: 0.670695
#
# Accuracy of the source=== dataset: 0.651591
# Accuracy of the target dataset: 0.347015
#
#  epoch: 20, [iter: 40 / all 40], err_s_label: 1.095035, err_s_domain: 0.704797, err_t_domain: 0.667458
#
# Accuracy of the source=== dataset: 0.654104
# Accuracy of the target dataset: 0.341418
#
#  epoch: 21, [iter: 40 / all 40], err_s_label: 1.088932, err_s_domain: 0.703425, err_t_domain: 0.664522
#
# Accuracy of the source=== dataset: 0.651591
# Accuracy of the target dataset: 0.339552
#
#  epoch: 22, [iter: 40 / all 40], err_s_label: 1.081943, err_s_domain: 0.702728, err_t_domain: 0.663575
#
# Accuracy of the source=== dataset: 0.652429
# Accuracy of the target dataset: 0.336754
#
#  epoch: 23, [iter: 40 / all 40], err_s_label: 1.075454, err_s_domain: 0.702798, err_t_domain: 0.666627
#
# Accuracy of the source=== dataset: 0.654941
# Accuracy of the target dataset: 0.336754
#
#  epoch: 24, [iter: 40 / all 40], err_s_label: 1.069863, err_s_domain: 0.704271, err_t_domain: 0.675584
#
# Accuracy of the source=== dataset: 0.655779
# Accuracy of the target dataset: 0.333955
#
#  epoch: 25, [iter: 40 / all 40], err_s_label: 1.064632, err_s_domain: 0.705790, err_t_domain: 0.685542
#
# Accuracy of the source=== dataset: 0.654941
# Accuracy of the target dataset: 0.335821
#
#  epoch: 26, [iter: 40 / all 40], err_s_label: 1.060423, err_s_domain: 0.706205, err_t_domain: 0.694251
#
# Accuracy of the source=== dataset: 0.653266
# Accuracy of the target dataset: 0.334888
#
#  epoch: 27, [iter: 40 / all 40], err_s_label: 1.056980, err_s_domain: 0.706911, err_t_domain: 0.698784
#
# Accuracy of the source=== dataset: 0.653266
# Accuracy of the target dataset: 0.331157
#
#  epoch: 28, [iter: 40 / all 40], err_s_label: 1.054188, err_s_domain: 0.707321, err_t_domain: 0.698376
#
# Accuracy of the source=== dataset: 0.654941
# Accuracy of the target dataset: 0.333022
#
#  epoch: 29, [iter: 40 / all 40], err_s_label: 1.051788, err_s_domain: 0.705623, err_t_domain: 0.695165
#
# Accuracy of the source=== dataset: 0.657454
# Accuracy of the target dataset: 0.333955
#
#  epoch: 30, [iter: 40 / all 40], err_s_label: 1.050132, err_s_domain: 0.702432, err_t_domain: 0.689444
#
# Accuracy of the source=== dataset: 0.659129
# Accuracy of the target dataset: 0.334888
#
#  epoch: 31, [iter: 40 / all 40], err_s_label: 1.048834, err_s_domain: 0.698755, err_t_domain: 0.684140
#
# Accuracy of the source=== dataset: 0.662479
# Accuracy of the target dataset: 0.333022
#
#  epoch: 32, [iter: 40 / all 40], err_s_label: 1.047831, err_s_domain: 0.695563, err_t_domain: 0.681473
#
# Accuracy of the source=== dataset: 0.664992
# Accuracy of the target dataset: 0.337687
#
#  epoch: 33, [iter: 40 / all 40], err_s_label: 1.047006, err_s_domain: 0.693347, err_t_domain: 0.683283
#
# Accuracy of the source=== dataset: 0.667504
# Accuracy of the target dataset: 0.338619
#
#  epoch: 34, [iter: 40 / all 40], err_s_label: 1.047166, err_s_domain: 0.692623, err_t_domain: 0.688841
#
# Accuracy of the source=== dataset: 0.669179
# Accuracy of the target dataset: 0.334888
#
#  epoch: 35, [iter: 40 / all 40], err_s_label: 1.048171, err_s_domain: 0.692895, err_t_domain: 0.695490
#
# Accuracy of the source=== dataset: 0.671692
# Accuracy of the target dataset: 0.338619
#
#  epoch: 36, [iter: 40 / all 40], err_s_label: 1.049652, err_s_domain: 0.693697, err_t_domain: 0.700627
#
# Accuracy of the source=== dataset: 0.676717
# Accuracy of the target dataset: 0.337687
#
#  epoch: 37, [iter: 40 / all 40], err_s_label: 1.048082, err_s_domain: 0.694223, err_t_domain: 0.703285
#
# Accuracy of the source=== dataset: 0.679229
# Accuracy of the target dataset: 0.335821
#
#  epoch: 38, [iter: 40 / all 40], err_s_label: 1.045503, err_s_domain: 0.694058, err_t_domain: 0.702017
#
# Accuracy of the source=== dataset: 0.681742
# Accuracy of the target dataset: 0.332090
#
#  epoch: 39, [iter: 40 / all 40], err_s_label: 1.043293, err_s_domain: 0.693914, err_t_domain: 0.698425
#
# Accuracy of the source=== dataset: 0.680905
# Accuracy of the target dataset: 0.332090
#
#  epoch: 40, [iter: 40 / all 40], err_s_label: 1.039417, err_s_domain: 0.694591, err_t_domain: 0.693806
#
# Accuracy of the source=== dataset: 0.681742
# Accuracy of the target dataset: 0.333022
#
#  epoch: 41, [iter: 40 / all 40], err_s_label: 1.036040, err_s_domain: 0.696666, err_t_domain: 0.688313
#
# Accuracy of the source=== dataset: 0.685092
# Accuracy of the target dataset: 0.336754
#
#  epoch: 42, [iter: 40 / all 40], err_s_label: 1.032610, err_s_domain: 0.699750, err_t_domain: 0.684370
#
# Accuracy of the source=== dataset: 0.687605
# Accuracy of the target dataset: 0.339552
#
#  epoch: 43, [iter: 40 / all 40], err_s_label: 1.030028, err_s_domain: 0.704166, err_t_domain: 0.682231
#
# Accuracy of the source=== dataset: 0.687605
# Accuracy of the target dataset: 0.338619
#
#  epoch: 44, [iter: 40 / all 40], err_s_label: 1.028023, err_s_domain: 0.708749, err_t_domain: 0.682960
#
# Accuracy of the source=== dataset: 0.689280
# Accuracy of the target dataset: 0.338619
#
#  epoch: 45, [iter: 40 / all 40], err_s_label: 1.026342, err_s_domain: 0.708351, err_t_domain: 0.684812
#
# Accuracy of the source=== dataset: 0.690117
# Accuracy of the target dataset: 0.342351
#
#  epoch: 46, [iter: 40 / all 40], err_s_label: 1.024961, err_s_domain: 0.704390, err_t_domain: 0.685745
#
# Accuracy of the source=== dataset: 0.691792
# Accuracy of the target dataset: 0.343284
#
#  epoch: 47, [iter: 40 / all 40], err_s_label: 1.024093, err_s_domain: 0.701724, err_t_domain: 0.684154
#
# Accuracy of the source=== dataset: 0.691792
# Accuracy of the target dataset: 0.343284
#
#  epoch: 48, [iter: 40 / all 40], err_s_label: 1.023185, err_s_domain: 0.699035, err_t_domain: 0.681903
#
# Accuracy of the source=== dataset: 0.690117
# Accuracy of the target dataset: 0.346082
#
#  epoch: 49, [iter: 40 / all 40], err_s_label: 1.021814, err_s_domain: 0.696688, err_t_domain: 0.680488
#
# Accuracy of the source=== dataset: 0.690117
# Accuracy of the target dataset: 0.343284
#
#  epoch: 50, [iter: 40 / all 40], err_s_label: 1.020446, err_s_domain: 0.695428, err_t_domain: 0.680358
#
# Accuracy of the source=== dataset: 0.690117
# Accuracy of the target dataset: 0.342351
#
#  epoch: 51, [iter: 40 / all 40], err_s_label: 1.019033, err_s_domain: 0.695064, err_t_domain: 0.682360
#
# Accuracy of the source=== dataset: 0.689280
# Accuracy of the target dataset: 0.341418
#
#  epoch: 52, [iter: 40 / all 40], err_s_label: 1.017425, err_s_domain: 0.695895, err_t_domain: 0.686719
#
# Accuracy of the source=== dataset: 0.690117
# Accuracy of the target dataset: 0.340485
#
#  epoch: 53, [iter: 40 / all 40], err_s_label: 1.015710, err_s_domain: 0.696389, err_t_domain: 0.691239
#
# Accuracy of the source=== dataset: 0.691792
# Accuracy of the target dataset: 0.340485
#
#  epoch: 54, [iter: 40 / all 40], err_s_label: 1.013955, err_s_domain: 0.696157, err_t_domain: 0.694724
#
# Accuracy of the source=== dataset: 0.693467
# Accuracy of the target dataset: 0.339552
#
#  epoch: 55, [iter: 40 / all 40], err_s_label: 1.012308, err_s_domain: 0.695436, err_t_domain: 0.698009
#
# Accuracy of the source=== dataset: 0.695980
# Accuracy of the target dataset: 0.339552
#
#  epoch: 56, [iter: 40 / all 40], err_s_label: 1.011046, err_s_domain: 0.694546, err_t_domain: 0.700176
#
# Accuracy of the source=== dataset: 0.695980
# Accuracy of the target dataset: 0.339552
#
#  epoch: 57, [iter: 40 / all 40], err_s_label: 1.009887, err_s_domain: 0.693520, err_t_domain: 0.701057
#
# Accuracy of the source=== dataset: 0.695142
# Accuracy of the target dataset: 0.341418
#
#  epoch: 58, [iter: 40 / all 40], err_s_label: 1.009369, err_s_domain: 0.692862, err_t_domain: 0.699480
#
# Accuracy of the source=== dataset: 0.694305
# Accuracy of the target dataset: 0.345149
#
#  epoch: 59, [iter: 40 / all 40], err_s_label: 1.009060, err_s_domain: 0.692340, err_t_domain: 0.696980
#
# Accuracy of the source=== dataset: 0.695980
# Accuracy of the target dataset: 0.342351
#
#  epoch: 60, [iter: 40 / all 40], err_s_label: 1.008623, err_s_domain: 0.692279, err_t_domain: 0.693799
#
# Accuracy of the source=== dataset: 0.695980
# Accuracy of the target dataset: 0.341418
#
#  epoch: 61, [iter: 40 / all 40], err_s_label: 1.007545, err_s_domain: 0.692323, err_t_domain: 0.690704
#
# Accuracy of the source=== dataset: 0.695142
# Accuracy of the target dataset: 0.342351
#
#  epoch: 62, [iter: 40 / all 40], err_s_label: 1.005917, err_s_domain: 0.692970, err_t_domain: 0.687896
#
# Accuracy of the source=== dataset: 0.697655
# Accuracy of the target dataset: 0.344216
#
#  epoch: 63, [iter: 40 / all 40], err_s_label: 1.004403, err_s_domain: 0.694181, err_t_domain: 0.686462
#
# Accuracy of the source=== dataset: 0.696817
# Accuracy of the target dataset: 0.346082
#
#  epoch: 64, [iter: 40 / all 40], err_s_label: 1.002940, err_s_domain: 0.696012, err_t_domain: 0.686800
#
# Accuracy of the source=== dataset: 0.696817
# Accuracy of the target dataset: 0.344216
#
#  epoch: 65, [iter: 40 / all 40], err_s_label: 1.002059, err_s_domain: 0.698630, err_t_domain: 0.687499
#
# Accuracy of the source=== dataset: 0.697655
# Accuracy of the target dataset: 0.343284
#
#  epoch: 66, [iter: 40 / all 40], err_s_label: 1.000999, err_s_domain: 0.701362, err_t_domain: 0.689547
#
# Accuracy of the source=== dataset: 0.698492
# Accuracy of the target dataset: 0.344216
#
#  epoch: 67, [iter: 40 / all 40], err_s_label: 0.999835, err_s_domain: 0.703631, err_t_domain: 0.691923
#
# Accuracy of the source=== dataset: 0.698492
# Accuracy of the target dataset: 0.347948
#
#  epoch: 68, [iter: 40 / all 40], err_s_label: 0.998639, err_s_domain: 0.701815, err_t_domain: 0.693129
#
# Accuracy of the source=== dataset: 0.698492
# Accuracy of the target dataset: 0.352612
#
#  epoch: 69, [iter: 40 / all 40], err_s_label: 0.997631, err_s_domain: 0.697034, err_t_domain: 0.690864
#
# Accuracy of the source=== dataset: 0.700168
# Accuracy of the target dataset: 0.350746
#
#  epoch: 70, [iter: 40 / all 40], err_s_label: 0.997141, err_s_domain: 0.694529, err_t_domain: 0.684609
#
# Accuracy of the source=== dataset: 0.701843
# Accuracy of the target dataset: 0.345149
#
#  epoch: 71, [iter: 40 / all 40], err_s_label: 0.997071, err_s_domain: 0.693935, err_t_domain: 0.679134
#
# Accuracy of the source=== dataset: 0.701005
# Accuracy of the target dataset: 0.343284
#
#  epoch: 72, [iter: 40 / all 40], err_s_label: 0.996800, err_s_domain: 0.693585, err_t_domain: 0.677878
#
# Accuracy of the source=== dataset: 0.701843
# Accuracy of the target dataset: 0.345149
#
#  epoch: 73, [iter: 40 / all 40], err_s_label: 0.996334, err_s_domain: 0.693890, err_t_domain: 0.680081
#
# Accuracy of the source=== dataset: 0.703518
# Accuracy of the target dataset: 0.342351
#
#  epoch: 74, [iter: 40 / all 40], err_s_label: 0.996135, err_s_domain: 0.694972, err_t_domain: 0.683933
#
# Accuracy of the source=== dataset: 0.704355
# Accuracy of the target dataset: 0.337687
#
#  epoch: 75, [iter: 40 / all 40], err_s_label: 0.996007, err_s_domain: 0.696737, err_t_domain: 0.686996
#
# Accuracy of the source=== dataset: 0.706030
# Accuracy of the target dataset: 0.336754
#
#  epoch: 76, [iter: 40 / all 40], err_s_label: 0.996036, err_s_domain: 0.697525, err_t_domain: 0.689870
#
# Accuracy of the source=== dataset: 0.706030
# Accuracy of the target dataset: 0.335821
#
#  epoch: 77, [iter: 40 / all 40], err_s_label: 0.995895, err_s_domain: 0.698141, err_t_domain: 0.693092
#
# Accuracy of the source=== dataset: 0.703518
# Accuracy of the target dataset: 0.339552
#
#  epoch: 78, [iter: 40 / all 40], err_s_label: 0.995675, err_s_domain: 0.697943, err_t_domain: 0.695890
#
# Accuracy of the source=== dataset: 0.702680
# Accuracy of the target dataset: 0.342351
#
#  epoch: 79, [iter: 40 / all 40], err_s_label: 0.995620, err_s_domain: 0.695760, err_t_domain: 0.698160
#
# Accuracy of the source=== dataset: 0.703518
# Accuracy of the target dataset: 0.345149
#
#  epoch: 80, [iter: 40 / all 40], err_s_label: 0.994976, err_s_domain: 0.693696, err_t_domain: 0.698857
#
# Accuracy of the source=== dataset: 0.702680
# Accuracy of the target dataset: 0.347948
#
#  epoch: 81, [iter: 40 / all 40], err_s_label: 0.994708, err_s_domain: 0.691733, err_t_domain: 0.698739
#
# Accuracy of the source=== dataset: 0.706030
# Accuracy of the target dataset: 0.348881
#
#  epoch: 82, [iter: 40 / all 40], err_s_label: 0.993975, err_s_domain: 0.690721, err_t_domain: 0.697769
#
# Accuracy of the source=== dataset: 0.706868
# Accuracy of the target dataset: 0.352612
#
#  epoch: 83, [iter: 40 / all 40], err_s_label: 0.993408, err_s_domain: 0.690447, err_t_domain: 0.696171
#
# Accuracy of the source=== dataset: 0.707705
# Accuracy of the target dataset: 0.347015
#
#  epoch: 84, [iter: 40 / all 40], err_s_label: 0.992715, err_s_domain: 0.690337, err_t_domain: 0.693948
#
# Accuracy of the source=== dataset: 0.706868
# Accuracy of the target dataset: 0.347015
#
#  epoch: 85, [iter: 40 / all 40], err_s_label: 0.992085, err_s_domain: 0.690519, err_t_domain: 0.690832
#
# Accuracy of the source=== dataset: 0.706030
# Accuracy of the target dataset: 0.347948
#
#  epoch: 86, [iter: 40 / all 40], err_s_label: 0.991426, err_s_domain: 0.690749, err_t_domain: 0.686869
#
# Accuracy of the source=== dataset: 0.705193
# Accuracy of the target dataset: 0.348881
#
#  epoch: 87, [iter: 40 / all 40], err_s_label: 0.991004, err_s_domain: 0.690941, err_t_domain: 0.682978
#
# Accuracy of the source=== dataset: 0.703518
# Accuracy of the target dataset: 0.347948
#
#  epoch: 88, [iter: 40 / all 40], err_s_label: 0.990130, err_s_domain: 0.691203, err_t_domain: 0.680352
#
# Accuracy of the source=== dataset: 0.705193
# Accuracy of the target dataset: 0.347015
#
#  epoch: 89, [iter: 40 / all 40], err_s_label: 0.989204, err_s_domain: 0.691654, err_t_domain: 0.679618
#
# Accuracy of the source=== dataset: 0.705193
# Accuracy of the target dataset: 0.346082
#
#  epoch: 90, [iter: 40 / all 40], err_s_label: 0.987910, err_s_domain: 0.692557, err_t_domain: 0.681592
#
# Accuracy of the source=== dataset: 0.706868
# Accuracy of the target dataset: 0.344216
#
#  epoch: 91, [iter: 40 / all 40], err_s_label: 0.986918, err_s_domain: 0.693842, err_t_domain: 0.684460
#
# Accuracy of the source=== dataset: 0.708543
# Accuracy of the target dataset: 0.346082
#
#  epoch: 92, [iter: 40 / all 40], err_s_label: 0.985988, err_s_domain: 0.695003, err_t_domain: 0.688033
#
# Accuracy of the source=== dataset: 0.709380
# Accuracy of the target dataset: 0.344216
#
#  epoch: 93, [iter: 40 / all 40], err_s_label: 0.985084, err_s_domain: 0.695911, err_t_domain: 0.691523
#
# Accuracy of the source=== dataset: 0.709380
# Accuracy of the target dataset: 0.343284
#
#  epoch: 94, [iter: 40 / all 40], err_s_label: 0.984892, err_s_domain: 0.696615, err_t_domain: 0.694351
#
# Accuracy of the source=== dataset: 0.709380
# Accuracy of the target dataset: 0.351679
#
#  epoch: 95, [iter: 40 / all 40], err_s_label: 0.984787, err_s_domain: 0.696868, err_t_domain: 0.697564
#
# Accuracy of the source=== dataset: 0.710218
# Accuracy of the target dataset: 0.348881
#
#  epoch: 96, [iter: 40 / all 40], err_s_label: 0.984750, err_s_domain: 0.696286, err_t_domain: 0.699436
#
# Accuracy of the source=== dataset: 0.710218
# Accuracy of the target dataset: 0.348881
#
#  epoch: 97, [iter: 40 / all 40], err_s_label: 0.984769, err_s_domain: 0.695725, err_t_domain: 0.699334
#
# Accuracy of the source=== dataset: 0.711893
# Accuracy of the target dataset: 0.347948
#
#  epoch: 98, [iter: 40 / all 40], err_s_label: 0.984576, err_s_domain: 0.695277, err_t_domain: 0.697913
#
# Accuracy of the source=== dataset: 0.712730
# Accuracy of the target dataset: 0.347015
#
#  epoch: 99, [iter: 40 / all 40], err_s_label: 0.984594, err_s_domain: 0.694882, err_t_domain: 0.696012
#
# Accuracy of the source=== dataset: 0.712730
# Accuracy of the target dataset: 0.347948
#
#  epoch: 100, [iter: 40 / all 40], err_s_label: 0.984612, err_s_domain: 0.694283, err_t_domain: 0.694244
#
# Accuracy of the source=== dataset: 0.711055
# Accuracy of the target dataset: 0.346082
#
#  epoch: 101, [iter: 40 / all 40], err_s_label: 0.984404, err_s_domain: 0.693420, err_t_domain: 0.693550
#
# Accuracy of the source=== dataset: 0.710218
# Accuracy of the target dataset: 0.347948
#
#  epoch: 102, [iter: 40 / all 40], err_s_label: 0.984468, err_s_domain: 0.693087, err_t_domain: 0.693608
#
# Accuracy of the source=== dataset: 0.711055
# Accuracy of the target dataset: 0.350746
#
#  epoch: 103, [iter: 40 / all 40], err_s_label: 0.984123, err_s_domain: 0.692948, err_t_domain: 0.693722
#
# Accuracy of the source=== dataset: 0.710218
# Accuracy of the target dataset: 0.349813
#
#  epoch: 104, [iter: 40 / all 40], err_s_label: 0.983445, err_s_domain: 0.692354, err_t_domain: 0.693599
#
# Accuracy of the source=== dataset: 0.710218
# Accuracy of the target dataset: 0.350746
#
#  epoch: 105, [iter: 40 / all 40], err_s_label: 0.982898, err_s_domain: 0.692133, err_t_domain: 0.692984
#
# Accuracy of the source=== dataset: 0.710218
# Accuracy of the target dataset: 0.351679
#
#  epoch: 106, [iter: 40 / all 40], err_s_label: 0.982042, err_s_domain: 0.692226, err_t_domain: 0.691881
#
# Accuracy of the source=== dataset: 0.711055
# Accuracy of the target dataset: 0.348881
#
#  epoch: 107, [iter: 40 / all 40], err_s_label: 0.981189, err_s_domain: 0.692469, err_t_domain: 0.690556
#
# Accuracy of the source=== dataset: 0.711055
# Accuracy of the target dataset: 0.347948
#
#  epoch: 108, [iter: 40 / all 40], err_s_label: 0.980624, err_s_domain: 0.692700, err_t_domain: 0.688899
#
# Accuracy of the source=== dataset: 0.711893
# Accuracy of the target dataset: 0.347948
#
#  epoch: 109, [iter: 40 / all 40], err_s_label: 0.980016, err_s_domain: 0.692678, err_t_domain: 0.687717
#
# Accuracy of the source=== dataset: 0.711055
# Accuracy of the target dataset: 0.347015
#
#  epoch: 110, [iter: 40 / all 40], err_s_label: 0.979963, err_s_domain: 0.692726, err_t_domain: 0.686561
#
# Accuracy of the source=== dataset: 0.710218
# Accuracy of the target dataset: 0.347948
#
#  epoch: 111, [iter: 40 / all 40], err_s_label: 0.979734, err_s_domain: 0.692570, err_t_domain: 0.685691
#
# Accuracy of the source=== dataset: 0.711893
# Accuracy of the target dataset: 0.348881
#
#  epoch: 112, [iter: 40 / all 40], err_s_label: 0.979519, err_s_domain: 0.692304, err_t_domain: 0.685309
#
# Accuracy of the source=== dataset: 0.713568
# Accuracy of the target dataset: 0.348881
#
#  epoch: 113, [iter: 40 / all 40], err_s_label: 0.979476, err_s_domain: 0.691905, err_t_domain: 0.685573
#
# Accuracy of the source=== dataset: 0.715243
# Accuracy of the target dataset: 0.349813
#
#  epoch: 114, [iter: 40 / all 40], err_s_label: 0.979375, err_s_domain: 0.691925, err_t_domain: 0.686298
#
# Accuracy of the source=== dataset: 0.715243
# Accuracy of the target dataset: 0.349813
#
#  epoch: 115, [iter: 40 / all 40], err_s_label: 0.979338, err_s_domain: 0.691801, err_t_domain: 0.688100
#
# Accuracy of the source=== dataset: 0.715243
# Accuracy of the target dataset: 0.350746
#
#  epoch: 116, [iter: 40 / all 40], err_s_label: 0.979288, err_s_domain: 0.691891, err_t_domain: 0.690825
#
# Accuracy of the source=== dataset: 0.713568
# Accuracy of the target dataset: 0.351679
#
#  epoch: 117, [iter: 40 / all 40], err_s_label: 0.979010, err_s_domain: 0.692256, err_t_domain: 0.693889
#
# Accuracy of the source=== dataset: 0.713568
# Accuracy of the target dataset: 0.353545
#
#  epoch: 118, [iter: 40 / all 40], err_s_label: 0.978483, err_s_domain: 0.692994, err_t_domain: 0.697375
#
# Accuracy of the source=== dataset: 0.715243
# Accuracy of the target dataset: 0.355410
#
#  epoch: 119, [iter: 40 / all 40], err_s_label: 0.978111, err_s_domain: 0.693637, err_t_domain: 0.700680
#
# Accuracy of the source=== dataset: 0.716918
# Accuracy of the target dataset: 0.355410
#
#  epoch: 120, [iter: 40 / all 40], err_s_label: 0.977684, err_s_domain: 0.694158, err_t_domain: 0.702955
#
# Accuracy of the source=== dataset: 0.716080
# Accuracy of the target dataset: 0.355410
#
#  epoch: 121, [iter: 40 / all 40], err_s_label: 0.977099, err_s_domain: 0.694293, err_t_domain: 0.703305
#
# Accuracy of the source=== dataset: 0.716080
# Accuracy of the target dataset: 0.357276
#
#  epoch: 122, [iter: 40 / all 40], err_s_label: 0.976516, err_s_domain: 0.693927, err_t_domain: 0.701987
#
# Accuracy of the source=== dataset: 0.716918
# Accuracy of the target dataset: 0.361007
#
#  epoch: 123, [iter: 40 / all 40], err_s_label: 0.976069, err_s_domain: 0.693130, err_t_domain: 0.699657
#
# Accuracy of the source=== dataset: 0.716918
# Accuracy of the target dataset: 0.361007
#
#  epoch: 124, [iter: 40 / all 40], err_s_label: 0.975694, err_s_domain: 0.692205, err_t_domain: 0.696817
#
# Accuracy of the source=== dataset: 0.717755
# Accuracy of the target dataset: 0.361007
#
#  epoch: 125, [iter: 40 / all 40], err_s_label: 0.975471, err_s_domain: 0.691576, err_t_domain: 0.694022
#
# Accuracy of the source=== dataset: 0.717755
# Accuracy of the target dataset: 0.359142
#
#  epoch: 126, [iter: 40 / all 40], err_s_label: 0.975145, err_s_domain: 0.690957, err_t_domain: 0.691948
#
# Accuracy of the source=== dataset: 0.717755
# Accuracy of the target dataset: 0.355410
#
#  epoch: 127, [iter: 40 / all 40], err_s_label: 0.974698, err_s_domain: 0.690607, err_t_domain: 0.690204
#
# Accuracy of the source=== dataset: 0.719430
# Accuracy of the target dataset: 0.355410
#
#  epoch: 128, [iter: 40 / all 40], err_s_label: 0.974378, err_s_domain: 0.690918, err_t_domain: 0.688775
#
# Accuracy of the source=== dataset: 0.720268
# Accuracy of the target dataset: 0.356343
#
#  epoch: 129, [iter: 40 / all 40], err_s_label: 0.974253, err_s_domain: 0.691464, err_t_domain: 0.688081
#
# Accuracy of the source=== dataset: 0.721106
# Accuracy of the target dataset: 0.356343
#
#  epoch: 130, [iter: 40 / all 40], err_s_label: 0.974272, err_s_domain: 0.692106, err_t_domain: 0.687858
#
# Accuracy of the source=== dataset: 0.721106
# Accuracy of the target dataset: 0.355410
#
#  epoch: 131, [iter: 40 / all 40], err_s_label: 0.974252, err_s_domain: 0.692728, err_t_domain: 0.687748
#
# Accuracy of the source=== dataset: 0.721943
# Accuracy of the target dataset: 0.356343
#
#  epoch: 132, [iter: 40 / all 40], err_s_label: 0.974283, err_s_domain: 0.692844, err_t_domain: 0.688032
#
# Accuracy of the source=== dataset: 0.721943
# Accuracy of the target dataset: 0.356343
#
#  epoch: 133, [iter: 40 / all 40], err_s_label: 0.974184, err_s_domain: 0.693256, err_t_domain: 0.688103
#
# Accuracy of the source=== dataset: 0.722781
# Accuracy of the target dataset: 0.355410
#
#  epoch: 134, [iter: 40 / all 40], err_s_label: 0.974207, err_s_domain: 0.693330, err_t_domain: 0.688505
#
# Accuracy of the source=== dataset: 0.723618
# Accuracy of the target dataset: 0.357276
#
#  epoch: 135, [iter: 40 / all 40], err_s_label: 0.974267, err_s_domain: 0.693463, err_t_domain: 0.688579
#
# Accuracy of the source=== dataset: 0.724456
# Accuracy of the target dataset: 0.353545
#
#  epoch: 136, [iter: 40 / all 40], err_s_label: 0.974299, err_s_domain: 0.693454, err_t_domain: 0.688632
#
# Accuracy of the source=== dataset: 0.724456
# Accuracy of the target dataset: 0.353545
#
#  epoch: 137, [iter: 40 / all 40], err_s_label: 0.974357, err_s_domain: 0.693279, err_t_domain: 0.688695
#
# Accuracy of the source=== dataset: 0.723618
# Accuracy of the target dataset: 0.352612
#
#  epoch: 138, [iter: 40 / all 40], err_s_label: 0.974518, err_s_domain: 0.693090, err_t_domain: 0.688820
#
# Accuracy of the source=== dataset: 0.723618
# Accuracy of the target dataset: 0.351679
#
#  epoch: 139, [iter: 40 / all 40], err_s_label: 0.974526, err_s_domain: 0.692913, err_t_domain: 0.689163
#
# Accuracy of the source=== dataset: 0.726131
# Accuracy of the target dataset: 0.351679
#
#  epoch: 140, [iter: 40 / all 40], err_s_label: 0.974731, err_s_domain: 0.692771, err_t_domain: 0.689699
#
# Accuracy of the source=== dataset: 0.726131
# Accuracy of the target dataset: 0.353545
#
#  epoch: 141, [iter: 40 / all 40], err_s_label: 0.974622, err_s_domain: 0.692506, err_t_domain: 0.690345
#
# Accuracy of the source=== dataset: 0.726131
# Accuracy of the target dataset: 0.354478
#
#  epoch: 142, [iter: 40 / all 40], err_s_label: 0.974451, err_s_domain: 0.692082, err_t_domain: 0.690978
#
# Accuracy of the source=== dataset: 0.726968
# Accuracy of the target dataset: 0.355410
#
#  epoch: 143, [iter: 40 / all 40], err_s_label: 0.974299, err_s_domain: 0.691668, err_t_domain: 0.691830
#
# Accuracy of the source=== dataset: 0.726131
# Accuracy of the target dataset: 0.358209
#
#  epoch: 144, [iter: 40 / all 40], err_s_label: 0.973999, err_s_domain: 0.691323, err_t_domain: 0.692966
#
# Accuracy of the source=== dataset: 0.726131
# Accuracy of the target dataset: 0.358209
#
#  epoch: 145, [iter: 40 / all 40], err_s_label: 0.973360, err_s_domain: 0.691157, err_t_domain: 0.694119
#
# Accuracy of the source=== dataset: 0.726131
# Accuracy of the target dataset: 0.358209
#
#  epoch: 146, [iter: 40 / all 40], err_s_label: 0.972795, err_s_domain: 0.690998, err_t_domain: 0.695448
#
# Accuracy of the source=== dataset: 0.726131
# Accuracy of the target dataset: 0.358209
#
#  epoch: 147, [iter: 40 / all 40], err_s_label: 0.972306, err_s_domain: 0.690667, err_t_domain: 0.696604
#
# Accuracy of the source=== dataset: 0.726968
# Accuracy of the target dataset: 0.358209
#
#  epoch: 148, [iter: 40 / all 40], err_s_label: 0.971562, err_s_domain: 0.690508, err_t_domain: 0.697280
#
# Accuracy of the source=== dataset: 0.727806
# Accuracy of the target dataset: 0.359142
#
#  epoch: 149, [iter: 40 / all 40], err_s_label: 0.971365, err_s_domain: 0.690470, err_t_domain: 0.697549
#
# Accuracy of the source=== dataset: 0.727806
# Accuracy of the target dataset: 0.359142
#
# ============ Summary =============
#
# Accuracy of the source dataset: 0.482412
# Accuracy of the target dataset: 0.370336
# Corresponding model was save in modelsmnist_mnistm_model_epoch_best.pth
